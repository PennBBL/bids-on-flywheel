# %% [markdown]
# # Grouping Edits for File Classifications
#
# In the case that you might want to edit a field uniformly, we can write a script that groups the acquisition files by certain fields. In this example, we show how to group the unique sequence names, TR, and voxel size.
#
# First, we query flywheel for the full project:

# %%
import flywheel
import pandas as pd
# add the script to the path
import sys
import os
sys.path.append(os.path.abspath("/home/ttapera/bids-on-flywheel/flywheel_bids_tools"))
import query_bids
import upload_bids
from tqdm import tqdm
import math
# Out:
# /data/joy/BBL/applications/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /data/joy/BBL/applications/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
fw = flywheel.Client()
result = query_bids.query_fw("Reward2018", fw)

# %% [markdown]
# Convert this to a dataframe:

# %%
view = fw.View(columns='subject')
subject_df = fw.read_view_dataframe(view, result.id)
sessions = []
view = fw.View(columns='acquisition')
pbar = tqdm(total=100)

for ind, row in subject_df.iterrows():
    session = fw.read_view_dataframe(view, row["subject.id"])
    if(session.shape[0] > 0):
        sessions.append(session)
    pbar.update(10)
pbar.close()
# Out:
# 3570it [00:42, 83.14it/s]

# %%
acquisitions = pd.concat(sessions)

# %% [markdown]
# And next, extract the acquisition's BIDS data.
#
# A slight modification we add to the BIDS extractor function is adding the file classification, Series name, and TR (what we assume will be useful grouping criteria)

# %%
#an example
ac = fw.get('5c744134ba25800039399544')

# see where the targets are?
ac.files
# Out:
# [{'classification': {},
#   'created': datetime.datetime(2019, 2, 25, 19, 29, 3, 179000, tzinfo=tzutc()),
#   'hash': '',
#   'id': '4039d74a-28e5-4b9d-b4c3-443e7e552329',
#   'info': {},
#   'info_exists': None,
#   'mimetype': 'text/xml',
#   'modality': None,
#   'modified': datetime.datetime(2019, 2, 25, 19, 29, 2, 875000, tzinfo=tzutc()),
#   'name': 'STIM_catalog.xml',
#   'origin': {'id': 'harshakethineni@flywheel.io',
#              'method': None,
#              'name': None,
#              'type': 'user',
#              'via': None},
#   'replaced': None,
#   'size': 564,
#   'tags': [],
#   'type': 'markup',
#   'zip_member_count': None}, {'classification': {},
#   'created': datetime.datetime(2019, 2, 25, 19, 29, 3, 499000, tzinfo=tzutc()),
#   'hash': '',
#   'id': '689da673-ce47-4787-ab88-09611c941497',
#   'info': {},
#   'info_exists': None,
#   'mimetype': 'text/xml',
#   'modality': None,
#   'modified': datetime.datetime(2019, 2, 25, 19, 29, 3, 199000, tzinfo=tzutc()),
#   'name': 'PRESENTATION_catalog.xml',
#   'origin': {'id': 'harshakethineni@flywheel.io',
#              'method': None,
#              'name': None,
#              'type': 'user',
#              'via': None},
#   'replaced': None,
#   'size': 564,
#   'tags': [],
#   'type': 'markup',
#   'zip_member_count': None}, {'classification': {},
#   'created': datetime.datetime(2019, 2, 25, 19, 29, 3, 645000, tzinfo=tzutc()),
#   'hash': '',
#   'id': 'aec1a851-dcd5-46f1-9ac5-f0049e270fcb',
#   'info': {},
#   'info_exists': None,
#   'mimetype': 'text/xml',
#   'modality': None,
#   'modified': datetime.datetime(2019, 2, 25, 19, 29, 3, 331000, tzinfo=tzutc()),
#   'name': 'ASSOCIATED_catalog.xml',
#   'origin': {'id': 'harshakethineni@flywheel.io',
#              'method': None,
#              'name': None,
#              'type': 'user',
#              'via': None},
#   'replaced': None,
#   'size': 883,
#   'tags': [],
#   'type': 'markup',
#   'zip_member_count': None}, {'classification': {},
#   'created': datetime.datetime(2019, 2, 25, 19, 29, 33, 996000, tzinfo=tzutc()),
#   'hash': '',
#   'id': '28479f94-a7d3-49b0-96a2-96111dc57227',
#   'info': {},
#   'info_exists': None,
#   'mimetype': 'application/octet-stream',
#   'modality': None,
#   'modified': datetime.datetime(2019, 2, 25, 19, 29, 33, 654000, tzinfo=tzutc()),
#   'name': '117226_20160220x10074.nii.gz',
#   'origin': {'id': 'harshakethineni@flywheel.io',
#              'method': None,
#              'name': None,
#              'type': 'user',
#              'via': None},
#   'replaced': None,
#   'size': 38925296,
#   'tags': [],
#   'type': 'nifti',
#   'zip_member_count': None}, {'classification': {'Measurement': ['Perfusion']},
#   'created': datetime.datetime(2019, 2, 25, 20, 40, 22, 413000, tzinfo=tzutc()),
#   'hash': '',
#   'id': '268eaf6e-a884-407d-8d80-a9bfd34657a4',
#   'info': {'AcquisitionDate': '20160220',
#            'AcquisitionMatrix': [64, 0, 0, 64],
#            'AcquisitionNumber': 1,
#            'AcquisitionTime': '133307.427500',
#            'AngioFlag': 'N',
#            'BitsAllocated': 16,
#            'BitsStored': 16,
#            'BodyPartExamined': 'BRAIN',
#            'Columns': 384,
#            'ContentDate': '20160220',
#            'ContentTime': '133309.970000',
#            'DateOfLastCalibration': [20090304, 20090304],
#            'DeviceSerialNumber': '66044',
#            'EchoNumbers': 1,
#            'EchoTime': 32,
#            'EchoTrainLength': 64,
#            'FlipAngle': 30,
#            'FrameOfReferenceUID': '1.3.12.2.1107.5.2.43.66044.1.20160220125620798.0.0.0',
#            'HighBit': 15,
#            'ImageOrientationPatient': [1, 0, 0, 0, 1, 0],
#            'ImagePositionPatient': [-720, -736, -62],
#            'ImageType': ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MOSAIC'],
#            'ImagedNucleus': '1H',
#            'ImagingFrequency': 123.252,
#            'InPlanePhaseEncodingDirection': 'COL',
#            'InstanceCreationDate': '20160220',
#            'InstanceCreationTime': '133309.970000',
#            'InstanceNumber': 1,
#            'InstitutionAddress': 'Curie Blvd. 422,Philadelphia,PA,US,19104',
#            'InstitutionName': 'University of Pennsylvania',
#            'LargestImagePixelValue': 20994,
#            'MRAcquisitionType': '2D',
#            'MagneticFieldStrength': 3,
#            'Manufacturer': 'SIEMENS',
#            'ManufacturerModelName': 'Prisma',
#            'Modality': 'MR',
#            'NumberOfAverages': 1,
#            'NumberOfFrames': 1,
#            'NumberOfPhaseEncodingSteps': 64,
#            'OperatorsName': 'KP',
#            'PatientAge': '023Y',
#            'PatientPosition': 'HFS',
#            'PatientSex': 'F',
#            'PatientSize': 1.7018,
#            'PatientWeight': 102.058,
#            'PercentPhaseFieldOfView': 100,
#            'PercentSampling': 100,
#            'PerformedProcedureStepDescription': 'CAMRIS^Satterthwaite',
#            'PerformedProcedureStepID': 'MR20160220122651',
#            'PerformedProcedureStepStartDate': '20160220',
#            'PerformedProcedureStepStartTime': '122651.384000',
#            'PerformingPhysicianName': 'SATTERTHWAITE',
#            'PhotometricInterpretation': 'MONOCHROME2',
#            'PhysiciansOfRecord': [],
#            'PixelBandwidth': 2055,
#            'PixelRepresentation': 0,
#            'PixelSpacing': [3, 3],
#            'ProtocolName': 'ASL_dicomref',
#            'RepetitionTime': 3000,
#            'RequestedProcedureDescription': 'CAMRIS Satterthwaite',
#            'Rows': 384,
#            'SAR': 0.0221817,
#            'SOPClassUID': 'MR Image Storage',
#            'SOPInstanceUID': '1.3.12.2.1107.5.2.43.66044.2016022013330976896540991',
#            'SamplesPerPixel': 1,
#            'ScanOptions': 'FS',
#            'ScanningSequence': 'EP',
#            'SequenceName': 'epfid2d1_64',
#            'SequenceVariant': ['SK', 'SS'],
#            'SeriesDate': '20160220',
#            'SeriesDescription': 'ASL_dicomref',
#            'SeriesInstanceUID': '1.3.12.2.1107.5.2.43.66044.2016022013330647206340891.0.0.0',
#            'SeriesNumber': 21,
#            'SeriesTime': '133309.964000',
#            'SliceLocation': -62.125,
#            'SliceThickness': 3.75,
#            'SmallestImagePixelValue': 0,
#            'SoftwareVersions': 'syngo MR D13D',
#            'SpacingBetweenSlices': 3.75,
#            'SpecificCharacterSet': 'ISO_IR 100',
#            'StationName': 'AWP66044',
#            'StudyDate': '20160220',
#            'StudyDescription': 'CAMRIS^Satterthwaite',
#            'StudyID': '1',
#            'StudyInstanceUID': '1.3.12.2.1107.5.2.43.66044.30000016021819095501800000040',
#            'StudyTime': '122651.332000',
#            'TimeOfLastCalibration': [123723.0, 123723.0],
#            'TransmitCoilName': 'Body',
#            'VariableFlipAngleFlag': 'N',
#            'WindowCenter': 7390,
#            'WindowCenterWidthExplanation': 'Algo1',
#            'WindowWidth': 15575,
#            'dBdt': 0},
#   'info_exists': None,
#   'mimetype': 'application/zip',
#   'modality': 'MR',
#   'modified': datetime.datetime(2019, 2, 25, 20, 40, 52, 553000, tzinfo=tzutc()),
#   'name': '21.dicom.zip',
#   'origin': {'id': 'harshakethineni@flywheel.io',
#              'method': None,
#              'name': None,
#              'type': 'user',
#              'via': None},
#   'replaced': None,
#   'size': 225181,
#   'tags': [],
#   'type': 'dicom',
#   'zip_member_count': 3}, {'classification': {'Measurement': ['Perfusion']},
#   'created': datetime.datetime(2019, 2, 25, 20, 41, 1, 931000, tzinfo=tzutc()),
#   'hash': 'v0-sha384-e0d9d6862b02075482dd069974e80ea46af254d67467324d5abfb6d0385511e66ae21144c04f8fb52c084f922b2d0ff8',
#   'id': '028a0ae1-b641-4746-be7a-5b44cadf5961',
#   'info': {'AcquisitionDateTime': '2016-02-20T13:33:7.427500',
#            'AcquisitionMatrixPE': 64,
#            'AcquisitionNumber': 1,
#            'AcquisitionTime': '13:33:7.427500',
#            'BandwidthPerPixelPhaseEncode': 28.409,
#            'BaseResolution': 64,
#            'BodyPartExamined': 'BRAIN',
#            'ConsistencyInfo': 'N4_VD13D_LATEST_20130810',
#            'ConversionSoftware': 'dcm2niix',
#            'ConversionSoftwareVersion': 'v1.0.20180918  (JP2:OpenJPEG) GCC4.8.4',
#            'DerivedVendorReportedEchoSpacing': 0.000550002,
#            'DeviceSerialNumber': '66044',
#            'EchoTime': 0.032,
#            'EchoTrainLength': 64,
#            'EffectiveEchoSpacing': 0.000550002,
#            'FlipAngle': 30,
#            'ImageOrientationPatientDICOM': [1, 0, 0, 0, 1, 0],
#            'ImageType': ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM', 'MOSAIC'],
#            'InPlanePhaseEncodingDirectionDICOM': 'COL',
#            'InstitutionAddress': 'Curie_Blvd._422_Philadelphia_PA_US_19104',
#            'InstitutionName': 'University_of_Pennsylvania',
#            'MRAcquisitionType': '2D',
#            'MagneticFieldStrength': 3,
#            'Manufacturer': 'Siemens',
#            'ManufacturersModelName': 'Prisma',
#            'Modality': 'MR',
#            'PartialFourier': 1,
#            'PatientPosition': 'HFS',
#            'PatientSex': 'F',
#            'PatientWeight': 102.058,
#            'PercentPhaseFOV': 100,
#            'PhaseEncodingDirection': 'j-',
#            'PhaseEncodingSteps': 64,
#            'PhaseResolution': 1,
#            'PixelBandwidth': 2055,
#            'ProcedureStepDescription': 'CAMRIS_Satterthwaite',
#            'ProtocolName': 'ASL_dicomref',
#            'PulseSequenceDetails': '%CustomerSeq%_cmrr_mbep2d_bold',
#            'ReceiveCoilActiveElements': 'HC1-7',
#            'ReceiveCoilName': 'HeadNeck_64',
#            'ReconMatrixPE': 64,
#            'RepetitionTime': 3,
#            'SAR': 0.0221817,
#            'ScanOptions': 'FS',
#            'ScanningSequence': 'EP',
#            'SequenceName': 'epfid2d1_64',
#            'SequenceVariant': 'SK_SS',
#            'SeriesDescription': 'ASL_dicomref',
#            'SeriesInstanceUID': '1.3.12.2.1107.5.2.43.66044.2016022013330647206340891.0.0.0',
#            'SeriesNumber': 21,
#            'ShimSetting': [3903, 2699, 509, 253, -51, -315, 115, -2],
#            'SliceThickness': 3.75,
#            'SliceTiming': [1.49,
#                            0,
#                            1.5825,
#                            0.0925,
#                            1.675,
#                            0.185,
#                            1.77,
#                            0.28,
#                            1.8625,
#                            0.3725,
#                            1.955,
#                            0.465,
#                            2.0475,
#                            0.5575,
#                            2.1425,
#                            0.6525,
#                            2.235,
#                            0.745,
#                            2.3275,
#                            0.8375,
#                            2.42,
#                            0.93,
#                            2.515,
#                            1.025,
#                            2.6075,
#                            1.1175,
#                            2.7,
#                            1.21,
#                            2.7925,
#                            1.3025,
#                            2.885,
#                            1.3975],
#            'SoftwareVersions': 'syngo_MR_D13D',
#            'SpacingBetweenSlices': 3.75,
#            'StationName': 'AWP66044',
#            'StudyID': '1',
#            'StudyInstanceUID': '1.3.12.2.1107.5.2.43.66044.30000016021819095501800000040',
#            'TotalReadoutTime': 0.0346501,
#            'TxRefAmp': 294.99,
#            'WipMemBlock': 'f91157a5-4cb4-43ee-976a-6b923c94034b||Sequence: '
#                           'vd13d/master r/d668381; Nov 12 2015 16:14:25 by eja'},
#   'info_exists': None,
#   'mimetype': 'application/octet-stream',
#   'modality': 'MR',
#   'modified': datetime.datetime(2019, 2, 25, 20, 41, 1, 319000, tzinfo=tzutc()),
#   'name': 'ASL_dicomref_21.nii.gz',
#   'origin': {'id': '5c7452d4ba25800038396ceb',
#              'method': None,
#              'name': None,
#              'type': 'job',
#              'via': None},
#   'replaced': None,
#   'size': 195292,
#   'tags': [],
#   'type': 'nifti',
#   'zip_member_count': None}]

# %%
def extract_bids_data(acquisitionID, client):
    """Extract the BIDS data of an acquisition

    A helper function to dig into the file.info container
    (a dictionary of dictionaries) and extract the BIDS validity fields.

    Parameters
    -------
    acquisitionID
        The mongoDB hash key to identify the object.
    client
        The flywheel Client class object.

    Returns
    --------
    df
        A table of the bids fields and values.
    """
    # create the acquisition object and pull the niftis
    try:
        acq = client.get(acquisitionID)
    except:
        #global NO_DATA
        #NO_DATA += 1
        return None
    niftis = [x for x in acq.files if x['type'] == 'nifti']
    # if there are no niftis, return
    if (len(niftis) < 1):
        #global UNCLASSIFIED
        #UNCLASSIFIED += 1
        return None
    else:
        df = []
        # for each nifti, if the info has a BIDS dict:
        for nii in niftis:
            info = nii['info']
            bids = {}
            # also add the acquisition id to the dict for joining purposes
            bids['acquisition.id'] = str(acquisitionID)
            
            # get bids classifier info if it exists
            if 'BIDS' in info.keys() and isinstance(info['BIDS'], dict):
                # pull out the bids info
                bids.update(nii['info']['BIDS'])

            # include the classification
            if 'classification' in nii.keys():
                bids.update(nii.classification)
            
            # get nifti info
            bids['SeriesDescription'] = info['SeriesDescription']
            bids['RepetitionTime'] = info['RepetitionTime']
            bids['SequenceName'] = info['SequenceName']
            bids['Modality'] = info['Modality']
            
            df.append(bids)

        return(df)

# %%
dd=extract_bids_data("5c1a8bbc9011bd0011369990", fw)

# %%
dd
# Out:
# [{'acquisition.id': '5c1a8bbc9011bd0011369990',
#   'Run': '',
#   'error_message': '',
#   'Ce': '',
#   'Filename': 'sub-120217_ses-nodra_T1w.nii.gz',
#   'ignore': False,
#   'Acq': '',
#   'valid': True,
#   'template': 'anat_file',
#   'Rec': '',
#   'Path': 'sub-120217/ses-nodra/anat',
#   'Folder': 'anat',
#   'Modality': 'MR',
#   'Mod': '',
#   'Intent': ['Structural'],
#   'Measurement': ['T1'],
#   'SeriesDescription': 'MPRAGE_NAVprotocol',
#   'RepetitionTime': 0.0112,
#   'SequenceName': 'Moco3d1_32ns'}]

# %%
# loop through the acquisitions to extract the bids validity data
bids_classifications = []
pbar = tqdm(total=100)
tempDF = acquisitions.iloc[:200,]
for ind, row in acquisitions.iloc[:200,].iterrows():
    temp_info = extract_bids_data(row["acquisition.id"], fw)
    if temp_info is not None:
        bids_classifications.extend(temp_info)
    pbar.update(10)
pbar.close()
bids_classifications = pd.DataFrame(bids_classifications)
# Out:
# 2000it [00:13, 157.00it/s]

# %% [markdown]
# Intent and measurement have been added, though as lists. We can still group by series description.

# %%
bids_classifications.drop_duplicates(['SeriesDescription', 'RepetitionTime'])
# Out:
#      Acq   Ce Custom Echo                                           Filename  \
# 0         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 1         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 2                NaN  NaN                     sub-90683_ses-nodra_T1w.nii.gz
# 3                NaN  NaN                     sub-90683_ses-nodra_T1w.nii.gz
# 4         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 5         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 7    NaN  NaN    NaN  NaN                                                NaN
# 10   NaN  NaN    NaN  NaN                                                NaN
# 11        NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 12   NaN  NaN    NaN  NaN                                                NaN
# 37        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 38        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 40        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 41        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 43   NaN  NaN    NaN  NaN                                                NaN
# 90        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 91        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 92        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 93        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 94               NaN  NaN                      sub-83835_ses-neff_T1w.nii.gz
# 100       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
# 101       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
# 108       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
#
#     Folder        Intent Measurement  Mod Modality  ...   RepetitionTime  Run  \
# 0     func  [Functional]       [T2*]  NaN       MR  ...           0.5000
# 1     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 2     anat  [Structural]        [T1]            MR  ...           1.8500
# 3     anat  [Structural]        [T1]            MR  ...           0.0112
# 4     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 5     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 7      NaN   [Localizer]        [T2]  NaN       MR  ...           0.0086  NaN
# 10     NaN        [Shim]         NaN  NaN       MR  ...           2.0000  NaN
# 11    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 12     NaN   [Localizer]        [T2]  NaN       MR  ...           0.0086  NaN
# 37    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 38    func  [Functional]       [T2*]  NaN       MR  ...           0.5000
# 40    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 41    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 43     NaN   [Localizer]        [T2]  NaN       MR  ...           0.0200  NaN
# 90    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 91    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 92    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 93    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 94    anat  [Structural]        [T1]            MR  ...           1.8100
# 100   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 101   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 108   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
#
#      SequenceName          SeriesDescription Task            acquisition.id  \
# 0     epfid2d1_64      bbl1_restbold_mb6_742       5c1a796d9011bd0014368993
# 1    _epfid2d1_64              ep2d_itc1_168       5c1a796d9011bd00153688c1
# 2         Moco3d1  MPRAGE_TI1110_ipat2_moco3  NaN  5c1a796e9011bd00133688e9
# 3    Moco3d1_32ns         MPRAGE_NAVprotocol  NaN  5c1a796e9011bd00133688ea
# 4    _epfid2d1_64              ep2d_itc2_168       5c1a796e9011bd0014368996
# 5    _epfid2d1_64         bbl1_restbold1_124       5c1a796e9011bd00113688d6
# 7          _fl2d1                  localizer  NaN  5c1a796e9011bd00133688eb
# 10   _epfid2d1_64      epi_singlerep_advshim  NaN  5c1a796e9011bd00153688c5
# 11   _epfid2d1_64         bbl1_restbold1_204       5c1a7ee19011bd0011368aac
# 12         _fl2d1         localizer_8channel  NaN  5c1a848d9011bd0014369702
# 37   _epfid2d1_64           ep2d_effort2_236       5c1a80139011bd0014368e9c
# 38    epfid2d1_64          ep2d_effort3_1416       5c1a80139011bd0015368c2d
# 40   _epfid2d1_64           ep2d_effort1_236       5c1a80139011bd0014368e9f
# 41   _epfid2d1_64                ep2d_single       5c1a80139011bd0013368cf2
# 43         _fl2d1                  localizer  NaN  5c1a80139011bd0014368ea3
# 90   _epfid2d1_64           ep2d_effort3_168       5c1a7e169011bd0011368985
# 91   _epfid2d1_64           ep2d_effort4_168       5c1a7e169011bd00133689d2
# 92   _epfid2d1_64           ep2d_effort2_168       5c1a7e179011bd0015368995
# 93   _epfid2d1_64           ep2d_effort1_168       5c1a7e179011bd0015368996
# 94        _tfl3d1        MPRAGE_TI1100_ipat2  NaN  5c1a7e179011bd001536899a
# 100  _epfid2d1_64              ep2d_itc3_168       5c1a7e179011bd00133689d3
# 101  _epfid2d1_64          ep2d_restbold_168       5c1a7e179011bd0011368989
# 108  _epfid2d1_64              ep2d_itc4_168       5c1a80899011bd0011368c81
#
#                                 error_message ignore   template  valid
# 0    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 1    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 2                                              False  anat_file   True
# 3                                              False  anat_file   True
# 4    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 5    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 7                                         NaN    NaN        NaN    NaN
# 10                                        NaN    NaN        NaN    NaN
# 11   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 12                                        NaN    NaN        NaN    NaN
# 37   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 38   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 40   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 41   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 43                                        NaN    NaN        NaN    NaN
# 90   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 91   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 92   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 93   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 94                                             False  anat_file   True
# 100  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 101  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 108  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
#
# [23 rows x 22 columns]

# %% [markdown]
# Note that this isn't *strictly* a grouped dataframe. We have effectively emulated grouping by dropping duplicate rows from specific columns. This means that within each group of non-duplicate columns, there are duplicate values in the full dataset; for example, there is only one line for MPRAGE_NAV, but there are 16 different values for other files. These fields, therefore, should not be changed en masse unless absolutely certain.

# %%
bids_classifications.groupby(['SeriesDescription', 'RepetitionTime']).count()
# Out:
#                                           Acq  Ce  Custom  Echo  Filename  \
# SeriesDescription         RepetitionTime
# MPRAGE_NAVprotocol        0.0112           16  16       0     0        16
# MPRAGE_TI1100_ipat2       1.8100            2   2       0     0         2
# MPRAGE_TI1110_ipat2_moco3 1.8500            8   8       0     0         8
# bbl1_restbold1_124        3.0000            6   0       1     6         6
# bbl1_restbold1_204        3.0000            1   0       0     1         1
# bbl1_restbold_mb6_742     0.5000            7   0       0     7         7
# ep2d_effort1_168          3.0000            1   0       0     1         1
# ep2d_effort1_236          3.0000            1   0       0     1         1
# ep2d_effort2_168          3.0000            1   0       0     1         1
# ep2d_effort2_236          3.0000            1   0       0     1         1
# ep2d_effort3_1416         0.5000            1   0       0     1         1
# ep2d_effort3_168          3.0000            1   0       0     1         1
# ep2d_effort4_168          3.0000            1   0       0     1         1
# ep2d_itc1_168             3.0000            8   0       0     8         8
# ep2d_itc2_168             3.0000            8   0       0     8         8
# ep2d_itc3_168             3.0000            1   0       0     1         1
# ep2d_itc4_168             3.0000            1   0       0     1         1
# ep2d_restbold_168         3.0000            1   0       0     1         1
# ep2d_single               3.0000            3   0       0     3         3
# epi_singlerep_advshim     2.0000            0   0       0     0         0
# localizer                 0.0086            0   0       0     0         0
#                           0.0200            0   0       0     0         0
# localizer_8channel        0.0086            0   0       0     0         0
#
#                                           Folder  Intent  Measurement  Mod  \
# SeriesDescription         RepetitionTime
# MPRAGE_NAVprotocol        0.0112              16      16           16   16
# MPRAGE_TI1100_ipat2       1.8100               2       2            2    2
# MPRAGE_TI1110_ipat2_moco3 1.8500               8       8            8    8
# bbl1_restbold1_124        3.0000               6       6            6    0
# bbl1_restbold1_204        3.0000               1       1            1    0
# bbl1_restbold_mb6_742     0.5000               7       7            7    0
# ep2d_effort1_168          3.0000               1       1            1    0
# ep2d_effort1_236          3.0000               1       1            1    0
# ep2d_effort2_168          3.0000               1       1            1    0
# ep2d_effort2_236          3.0000               1       1            1    0
# ep2d_effort3_1416         0.5000               1       1            1    0
# ep2d_effort3_168          3.0000               1       1            1    0
# ep2d_effort4_168          3.0000               1       1            1    0
# ep2d_itc1_168             3.0000               8       8            8    0
# ep2d_itc2_168             3.0000               8       8            8    0
# ep2d_itc3_168             3.0000               1       1            1    0
# ep2d_itc4_168             3.0000               1       1            1    0
# ep2d_restbold_168         3.0000               1       1            1    0
# ep2d_single               3.0000               3       3            3    0
# epi_singlerep_advshim     2.0000               0       7            0    0
# localizer                 0.0086               0      21           21    0
#                           0.0200               0       9            9    0
# localizer_8channel        0.0086               0       3            3    0
#
#                                           Modality  Path  Rec  Run  \
# SeriesDescription         RepetitionTime
# MPRAGE_NAVprotocol        0.0112                16    16   16   16
# MPRAGE_TI1100_ipat2       1.8100                 2     2    2    2
# MPRAGE_TI1110_ipat2_moco3 1.8500                 8     8    8    8
# bbl1_restbold1_124        3.0000                 6     6    6    6
# bbl1_restbold1_204        3.0000                 1     1    1    1
# bbl1_restbold_mb6_742     0.5000                 7     7    7    7
# ep2d_effort1_168          3.0000                 1     1    1    1
# ep2d_effort1_236          3.0000                 1     1    1    1
# ep2d_effort2_168          3.0000                 1     1    1    1
# ep2d_effort2_236          3.0000                 1     1    1    1
# ep2d_effort3_1416         0.5000                 1     1    1    1
# ep2d_effort3_168          3.0000                 1     1    1    1
# ep2d_effort4_168          3.0000                 1     1    1    1
# ep2d_itc1_168             3.0000                 8     8    8    8
# ep2d_itc2_168             3.0000                 8     8    8    8
# ep2d_itc3_168             3.0000                 1     1    1    1
# ep2d_itc4_168             3.0000                 1     1    1    1
# ep2d_restbold_168         3.0000                 1     1    1    1
# ep2d_single               3.0000                 3     3    3    3
# epi_singlerep_advshim     2.0000                 7     0    0    0
# localizer                 0.0086                21     0    0    0
#                           0.0200                 9     0    0    0
# localizer_8channel        0.0086                 3     0    0    0
#
#                                           SequenceName  Task  acquisition.id  \
# SeriesDescription         RepetitionTime
# MPRAGE_NAVprotocol        0.0112                    16     0              16
# MPRAGE_TI1100_ipat2       1.8100                     2     0               2
# MPRAGE_TI1110_ipat2_moco3 1.8500                     8     0               8
# bbl1_restbold1_124        3.0000                     6     6               6
# bbl1_restbold1_204        3.0000                     1     1               1
# bbl1_restbold_mb6_742     0.5000                     7     7               7
# ep2d_effort1_168          3.0000                     1     1               1
# ep2d_effort1_236          3.0000                     1     1               1
# ep2d_effort2_168          3.0000                     1     1               1
# ep2d_effort2_236          3.0000                     1     1               1
# ep2d_effort3_1416         0.5000                     1     1               1
# ep2d_effort3_168          3.0000                     1     1               1
# ep2d_effort4_168          3.0000                     1     1               1
# ep2d_itc1_168             3.0000                     8     8               8
# ep2d_itc2_168             3.0000                     8     8               8
# ep2d_itc3_168             3.0000                     1     1               1
# ep2d_itc4_168             3.0000                     1     1               1
# ep2d_restbold_168         3.0000                     1     1               1
# ep2d_single               3.0000                     3     3               3
# epi_singlerep_advshim     2.0000                     7     0               7
# localizer                 0.0086                    21     0              21
#                           0.0200                     9     0               9
# localizer_8channel        0.0086                     3     0               3
#
#                                           error_message  ignore  template  \
# SeriesDescription         RepetitionTime
# MPRAGE_NAVprotocol        0.0112                     16      16        16
# MPRAGE_TI1100_ipat2       1.8100                      2       2         2
# MPRAGE_TI1110_ipat2_moco3 1.8500                      8       8         8
# bbl1_restbold1_124        3.0000                      6       6         6
# bbl1_restbold1_204        3.0000                      1       1         1
# bbl1_restbold_mb6_742     0.5000                      7       7         7
# ep2d_effort1_168          3.0000                      1       1         1
# ep2d_effort1_236          3.0000                      1       1         1
# ep2d_effort2_168          3.0000                      1       1         1
# ep2d_effort2_236          3.0000                      1       1         1
# ep2d_effort3_1416         0.5000                      1       1         1
# ep2d_effort3_168          3.0000                      1       1         1
# ep2d_effort4_168          3.0000                      1       1         1
# ep2d_itc1_168             3.0000                      8       8         8
# ep2d_itc2_168             3.0000                      8       8         8
# ep2d_itc3_168             3.0000                      1       1         1
# ep2d_itc4_168             3.0000                      1       1         1
# ep2d_restbold_168         3.0000                      1       1         1
# ep2d_single               3.0000                      3       3         3
# epi_singlerep_advshim     2.0000                      0       0         0
# localizer                 0.0086                      0       0         0
#                           0.0200                      0       0         0
# localizer_8channel        0.0086                      0       0         0
#
#                                           valid
# SeriesDescription         RepetitionTime
# MPRAGE_NAVprotocol        0.0112             16
# MPRAGE_TI1100_ipat2       1.8100              2
# MPRAGE_TI1110_ipat2_moco3 1.8500              8
# bbl1_restbold1_124        3.0000              6
# bbl1_restbold1_204        3.0000              1
# bbl1_restbold_mb6_742     0.5000              7
# ep2d_effort1_168          3.0000              1
# ep2d_effort1_236          3.0000              1
# ep2d_effort2_168          3.0000              1
# ep2d_effort2_236          3.0000              1
# ep2d_effort3_1416         0.5000              1
# ep2d_effort3_168          3.0000              1
# ep2d_effort4_168          3.0000              1
# ep2d_itc1_168             3.0000              8
# ep2d_itc2_168             3.0000              8
# ep2d_itc3_168             3.0000              1
# ep2d_itc4_168             3.0000              1
# ep2d_restbold_168         3.0000              1
# ep2d_single               3.0000              3
# epi_singlerep_advshim     2.0000              0
# localizer                 0.0086              0
#                           0.0200              0
# localizer_8channel        0.0086              0

# %% [markdown]
# As an aside, we should also have a system for dealing with list objects in columns:

# %%
bids_classifications.Intent.values
# Out:
# array([list(['Functional']), list(['Functional']), list(['Structural']),
#        list(['Structural']), list(['Functional']), list(['Functional']),
#        list(['Structural']), list(['Localizer']), list(['Localizer']),
#        list(['Localizer']), list(['Shim']), list(['Functional']),
#        list(['Localizer']), list(['Localizer']), list(['Localizer']),
#        list(['Functional']), list(['Functional']), list(['Functional']),
#        list(['Structural']), list(['Structural']), list(['Functional']),
#        list(['Structural']), list(['Shim']), list(['Localizer']),
#        list(['Localizer']), list(['Localizer']), list(['Functional']),
#        list(['Structural']), list(['Functional']), list(['Structural']),
#        list(['Functional']), list(['Structural']), list(['Shim']),
#        list(['Localizer']), list(['Localizer']), list(['Localizer']),
#        list(['Structural']), list(['Functional']), list(['Functional']),
#        list(['Structural']), list(['Functional']), list(['Functional']),
#        list(['Structural']), list(['Localizer']), list(['Localizer']),
#        list(['Localizer']), list(['Functional']), list(['Functional']),
#        list(['Functional']), list(['Structural']), list(['Structural']),
#        list(['Functional']), list(['Structural']), list(['Shim']),
#        list(['Localizer']), list(['Localizer']), list(['Localizer']),
#        list(['Functional']), list(['Functional']), list(['Functional']),
#        list(['Structural']), list(['Structural']), list(['Functional']),
#        list(['Structural']), list(['Shim']), list(['Localizer']),
#        list(['Localizer']), list(['Localizer']), list(['Functional']),
#        list(['Functional']), list(['Functional']), list(['Structural']),
#        list(['Structural']), list(['Functional']), list(['Structural']),
#        list(['Shim']), list(['Localizer']), list(['Localizer']),
#        list(['Localizer']), list(['Functional']), list(['Functional']),
#        list(['Functional']), list(['Structural']), list(['Structural']),
#        list(['Functional']), list(['Structural']), list(['Shim']),
#        list(['Localizer']), list(['Localizer']), list(['Localizer']),
#        list(['Functional']), list(['Functional']), list(['Functional']),
#        list(['Functional']), list(['Structural']), list(['Localizer']),
#        list(['Localizer']), list(['Localizer']), list(['Functional']),
#        list(['Functional']), list(['Functional']), list(['Functional']),
#        list(['Functional']), list(['Structural']), list(['Localizer']),
#        list(['Localizer']), list(['Localizer']), list(['Functional']),
#        list(['Functional'])], dtype=object)

# %%
def unlist_item(ls):
    
    if type(ls) is list:
        ls.sort()
        return(', '.join(x for x in ls))
    else:
        return float('nan')

# %%
l = ['Functional']
unlist_item(l)
# Out:
# 'Functional'

# %%
bids_classifications.Measurement.apply(unlist_item)
# Out:
# 0      T2*
# 1      T2*
# 2       T1
# 3       T1
# 4      T2*
# 5      T2*
# 6       T1
# 7       T2
# 8       T2
# 9       T2
# 10     NaN
# 11     T2*
# 12      T2
# 13      T2
# 14      T2
# 15     T2*
# 16     T2*
# 17     T2*
# 18      T1
# 19      T1
# 20     T2*
# 21      T1
# 22     NaN
# 23      T2
# 24      T2
# 25      T2
# 26     T2*
# 27      T1
# 28     T2*
# 29      T1
#       ...
# 79     T2*
# 80     T2*
# 81     T2*
# 82      T1
# 83      T1
# 84     T2*
# 85      T1
# 86     NaN
# 87      T2
# 88      T2
# 89      T2
# 90     T2*
# 91     T2*
# 92     T2*
# 93     T2*
# 94      T1
# 95      T2
# 96      T2
# 97      T2
# 98     T2*
# 99     T2*
# 100    T2*
# 101    T2*
# 102    T2*
# 103     T1
# 104     T2
# 105     T2
# 106     T2
# 107    T2*
# 108    T2*
# Name: Measurement, Length: 109, dtype: object

# %%
def relist_item(string):
    
    if type(string) is str:
        return(string.split(','))
    else:
        return(float('nan'))

# %%
bids_classifications.Measurement.apply(unlist_item).apply(relist_item)
# Out:
# 0      [T2*]
# 1      [T2*]
# 2       [T1]
# 3       [T1]
# 4      [T2*]
# 5      [T2*]
# 6       [T1]
# 7       [T2]
# 8       [T2]
# 9       [T2]
# 10       NaN
# 11     [T2*]
# 12      [T2]
# 13      [T2]
# 14      [T2]
# 15     [T2*]
# 16     [T2*]
# 17     [T2*]
# 18      [T1]
# 19      [T1]
# 20     [T2*]
# 21      [T1]
# 22       NaN
# 23      [T2]
# 24      [T2]
# 25      [T2]
# 26     [T2*]
# 27      [T1]
# 28     [T2*]
# 29      [T1]
#        ...
# 79     [T2*]
# 80     [T2*]
# 81     [T2*]
# 82      [T1]
# 83      [T1]
# 84     [T2*]
# 85      [T1]
# 86       NaN
# 87      [T2]
# 88      [T2]
# 89      [T2]
# 90     [T2*]
# 91     [T2*]
# 92     [T2*]
# 93     [T2*]
# 94      [T1]
# 95      [T2]
# 96      [T2]
# 97      [T2]
# 98     [T2*]
# 99     [T2*]
# 100    [T2*]
# 101    [T2*]
# 102    [T2*]
# 103     [T1]
# 104     [T2]
# 105     [T2]
# 106     [T2]
# 107    [T2*]
# 108    [T2*]
# Name: Measurement, Length: 109, dtype: object

# %% [markdown]
# Now that the list columsn are taken care of, we can attempt to edit something in a grouped view, and map that edit to the full dataframe.

# %%
grouped_view = bids_classifications.drop_duplicates(['SeriesDescription', 'RepetitionTime'])

# %%
grouped_view
# Out:
#      Acq   Ce Custom Echo                                           Filename  \
# 0         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 1         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 2                NaN  NaN                     sub-90683_ses-nodra_T1w.nii.gz
# 3                NaN  NaN                     sub-90683_ses-nodra_T1w.nii.gz
# 4         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 5         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 7    NaN  NaN    NaN  NaN                                                NaN
# 10   NaN  NaN    NaN  NaN                                                NaN
# 11        NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 12   NaN  NaN    NaN  NaN                                                NaN
# 37        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 38        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 40        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 41        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 43   NaN  NaN    NaN  NaN                                                NaN
# 90        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 91        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 92        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 93        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 94               NaN  NaN                      sub-83835_ses-neff_T1w.nii.gz
# 100       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
# 101       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
# 108       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
#
#     Folder        Intent Measurement  Mod Modality  ...   RepetitionTime  Run  \
# 0     func  [Functional]       [T2*]  NaN       MR  ...           0.5000
# 1     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 2     anat  [Structural]        [T1]            MR  ...           1.8500
# 3     anat  [Structural]        [T1]            MR  ...           0.0112
# 4     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 5     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 7      NaN   [Localizer]        [T2]  NaN       MR  ...           0.0086  NaN
# 10     NaN        [Shim]         NaN  NaN       MR  ...           2.0000  NaN
# 11    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 12     NaN   [Localizer]        [T2]  NaN       MR  ...           0.0086  NaN
# 37    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 38    func  [Functional]       [T2*]  NaN       MR  ...           0.5000
# 40    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 41    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 43     NaN   [Localizer]        [T2]  NaN       MR  ...           0.0200  NaN
# 90    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 91    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 92    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 93    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 94    anat  [Structural]        [T1]            MR  ...           1.8100
# 100   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 101   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 108   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
#
#      SequenceName          SeriesDescription Task            acquisition.id  \
# 0     epfid2d1_64      bbl1_restbold_mb6_742       5c1a796d9011bd0014368993
# 1    _epfid2d1_64              ep2d_itc1_168       5c1a796d9011bd00153688c1
# 2         Moco3d1  MPRAGE_TI1110_ipat2_moco3  NaN  5c1a796e9011bd00133688e9
# 3    Moco3d1_32ns         MPRAGE_NAVprotocol  NaN  5c1a796e9011bd00133688ea
# 4    _epfid2d1_64              ep2d_itc2_168       5c1a796e9011bd0014368996
# 5    _epfid2d1_64         bbl1_restbold1_124       5c1a796e9011bd00113688d6
# 7          _fl2d1                  localizer  NaN  5c1a796e9011bd00133688eb
# 10   _epfid2d1_64      epi_singlerep_advshim  NaN  5c1a796e9011bd00153688c5
# 11   _epfid2d1_64         bbl1_restbold1_204       5c1a7ee19011bd0011368aac
# 12         _fl2d1         localizer_8channel  NaN  5c1a848d9011bd0014369702
# 37   _epfid2d1_64           ep2d_effort2_236       5c1a80139011bd0014368e9c
# 38    epfid2d1_64          ep2d_effort3_1416       5c1a80139011bd0015368c2d
# 40   _epfid2d1_64           ep2d_effort1_236       5c1a80139011bd0014368e9f
# 41   _epfid2d1_64                ep2d_single       5c1a80139011bd0013368cf2
# 43         _fl2d1                  localizer  NaN  5c1a80139011bd0014368ea3
# 90   _epfid2d1_64           ep2d_effort3_168       5c1a7e169011bd0011368985
# 91   _epfid2d1_64           ep2d_effort4_168       5c1a7e169011bd00133689d2
# 92   _epfid2d1_64           ep2d_effort2_168       5c1a7e179011bd0015368995
# 93   _epfid2d1_64           ep2d_effort1_168       5c1a7e179011bd0015368996
# 94        _tfl3d1        MPRAGE_TI1100_ipat2  NaN  5c1a7e179011bd001536899a
# 100  _epfid2d1_64              ep2d_itc3_168       5c1a7e179011bd00133689d3
# 101  _epfid2d1_64          ep2d_restbold_168       5c1a7e179011bd0011368989
# 108  _epfid2d1_64              ep2d_itc4_168       5c1a80899011bd0011368c81
#
#                                 error_message ignore   template  valid
# 0    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 1    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 2                                              False  anat_file   True
# 3                                              False  anat_file   True
# 4    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 5    Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 7                                         NaN    NaN        NaN    NaN
# 10                                        NaN    NaN        NaN    NaN
# 11   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 12                                        NaN    NaN        NaN    NaN
# 37   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 38   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 40   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 41   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 43                                        NaN    NaN        NaN    NaN
# 90   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 91   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 92   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 93   Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 94                                             False  anat_file   True
# 100  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 101  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 108  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
#
# [23 rows x 22 columns]

# %% [markdown]
# Using effort as an example, we can change the task for each of them to "Effort".

# %%
mask = grouped_view['SeriesDescription'] == "ep2d_effort1_168"

# %%
mask = grouped_view['SeriesDescription'].str.contains("effort")
grouped_view.loc[mask,]
# Out:
#    Acq   Ce Custom Echo                                           Filename  \
# 37      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 38      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 40      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 90      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 91      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 92      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 93      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
#
#    Folder        Intent Measurement  Mod Modality  ...   RepetitionTime Run  \
# 37   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 38   func  [Functional]       [T2*]  NaN       MR  ...              0.5
# 40   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 90   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 91   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 92   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 93   func  [Functional]       [T2*]  NaN       MR  ...              3.0
#
#     SequenceName  SeriesDescription Task            acquisition.id  \
# 37  _epfid2d1_64   ep2d_effort2_236       5c1a80139011bd0014368e9c
# 38   epfid2d1_64  ep2d_effort3_1416       5c1a80139011bd0015368c2d
# 40  _epfid2d1_64   ep2d_effort1_236       5c1a80139011bd0014368e9f
# 90  _epfid2d1_64   ep2d_effort3_168       5c1a7e169011bd0011368985
# 91  _epfid2d1_64   ep2d_effort4_168       5c1a7e169011bd00133689d2
# 92  _epfid2d1_64   ep2d_effort2_168       5c1a7e179011bd0015368995
# 93  _epfid2d1_64   ep2d_effort1_168       5c1a7e179011bd0015368996
#
#                                error_message ignore   template  valid
# 37  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 38  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 40  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 90  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 91  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 92  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 93  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
#
# [7 rows x 22 columns]

# %%
grouped_view.loc[mask, 'Task'] = "Effort"
# Out:
# /data/joy/BBL/applications/miniconda3/lib/python3.6/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
grouped_view.loc[mask,]
# Out:
#    Acq   Ce Custom Echo                                           Filename  \
# 37      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 38      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 40      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 90      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 91      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 92      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 93      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
#
#    Folder        Intent Measurement  Mod Modality  ...   RepetitionTime Run  \
# 37   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 38   func  [Functional]       [T2*]  NaN       MR  ...              0.5
# 40   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 90   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 91   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 92   func  [Functional]       [T2*]  NaN       MR  ...              3.0
# 93   func  [Functional]       [T2*]  NaN       MR  ...              3.0
#
#     SequenceName  SeriesDescription    Task            acquisition.id  \
# 37  _epfid2d1_64   ep2d_effort2_236  Effort  5c1a80139011bd0014368e9c
# 38   epfid2d1_64  ep2d_effort3_1416  Effort  5c1a80139011bd0015368c2d
# 40  _epfid2d1_64   ep2d_effort1_236  Effort  5c1a80139011bd0014368e9f
# 90  _epfid2d1_64   ep2d_effort3_168  Effort  5c1a7e169011bd0011368985
# 91  _epfid2d1_64   ep2d_effort4_168  Effort  5c1a7e169011bd00133689d2
# 92  _epfid2d1_64   ep2d_effort2_168  Effort  5c1a7e179011bd0015368995
# 93  _epfid2d1_64   ep2d_effort1_168  Effort  5c1a7e179011bd0015368996
#
#                                error_message ignore   template  valid
# 37  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 38  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 40  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 90  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 91  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 92  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 93  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
#
# [7 rows x 22 columns]

# %% [markdown]
# Let's also change the run to correspond with the series description:

# %%
mask = grouped_view['SeriesDescription'].str.contains("effort1")
grouped_view.loc[mask,'Run'] = 1
mask = grouped_view['SeriesDescription'].str.contains("effort2")
grouped_view.loc[mask,'Run'] = 2
mask = grouped_view['SeriesDescription'].str.contains("effort3")
grouped_view.loc[mask,'Run'] = 3
mask = grouped_view['SeriesDescription'].str.contains("effort4")
grouped_view.loc[mask,'Run'] = 4

grouped_view
# Out:
#      Acq   Ce Custom Echo                                           Filename  \
# 0         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 1         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 2                NaN  NaN                     sub-90683_ses-nodra_T1w.nii.gz
# 3                NaN  NaN                     sub-90683_ses-nodra_T1w.nii.gz
# 4         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 5         NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 7    NaN  NaN    NaN  NaN                                                NaN
# 10   NaN  NaN    NaN  NaN                                                NaN
# 11        NaN    NaN       sub-90683_ses-nodra_task-{file.info.BIDS.Task}...
# 12   NaN  NaN    NaN  NaN                                                NaN
# 37        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 38        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 40        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 41        NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 43   NaN  NaN    NaN  NaN                                                NaN
# 90        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 91        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 92        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 93        NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 94               NaN  NaN                      sub-83835_ses-neff_T1w.nii.gz
# 100       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
# 101       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
# 108       NaN    NaN       sub-16349_ses-fndm1_task-{file.info.BIDS.Task}...
#
#     Folder        Intent Measurement  Mod Modality  ...   RepetitionTime  Run  \
# 0     func  [Functional]       [T2*]  NaN       MR  ...           0.5000
# 1     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 2     anat  [Structural]        [T1]            MR  ...           1.8500
# 3     anat  [Structural]        [T1]            MR  ...           0.0112
# 4     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 5     func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 7      NaN   [Localizer]        [T2]  NaN       MR  ...           0.0086  NaN
# 10     NaN        [Shim]         NaN  NaN       MR  ...           2.0000  NaN
# 11    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 12     NaN   [Localizer]        [T2]  NaN       MR  ...           0.0086  NaN
# 37    func  [Functional]       [T2*]  NaN       MR  ...           3.0000    2
# 38    func  [Functional]       [T2*]  NaN       MR  ...           0.5000    3
# 40    func  [Functional]       [T2*]  NaN       MR  ...           3.0000    1
# 41    func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 43     NaN   [Localizer]        [T2]  NaN       MR  ...           0.0200  NaN
# 90    func  [Functional]       [T2*]  NaN       MR  ...           3.0000    3
# 91    func  [Functional]       [T2*]  NaN       MR  ...           3.0000    4
# 92    func  [Functional]       [T2*]  NaN       MR  ...           3.0000    2
# 93    func  [Functional]       [T2*]  NaN       MR  ...           3.0000    1
# 94    anat  [Structural]        [T1]            MR  ...           1.8100
# 100   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 101   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
# 108   func  [Functional]       [T2*]  NaN       MR  ...           3.0000
#
#      SequenceName          SeriesDescription    Task  \
# 0     epfid2d1_64      bbl1_restbold_mb6_742
# 1    _epfid2d1_64              ep2d_itc1_168
# 2         Moco3d1  MPRAGE_TI1110_ipat2_moco3     NaN
# 3    Moco3d1_32ns         MPRAGE_NAVprotocol     NaN
# 4    _epfid2d1_64              ep2d_itc2_168
# 5    _epfid2d1_64         bbl1_restbold1_124
# 7          _fl2d1                  localizer     NaN
# 10   _epfid2d1_64      epi_singlerep_advshim     NaN
# 11   _epfid2d1_64         bbl1_restbold1_204
# 12         _fl2d1         localizer_8channel     NaN
# 37   _epfid2d1_64           ep2d_effort2_236  Effort
# 38    epfid2d1_64          ep2d_effort3_1416  Effort
# 40   _epfid2d1_64           ep2d_effort1_236  Effort
# 41   _epfid2d1_64                ep2d_single
# 43         _fl2d1                  localizer     NaN
# 90   _epfid2d1_64           ep2d_effort3_168  Effort
# 91   _epfid2d1_64           ep2d_effort4_168  Effort
# 92   _epfid2d1_64           ep2d_effort2_168  Effort
# 93   _epfid2d1_64           ep2d_effort1_168  Effort
# 94        _tfl3d1        MPRAGE_TI1100_ipat2     NaN
# 100  _epfid2d1_64              ep2d_itc3_168
# 101  _epfid2d1_64          ep2d_restbold_168
# 108  _epfid2d1_64              ep2d_itc4_168
#
#                acquisition.id                             error_message  \
# 0    5c1a796d9011bd0014368993  Task u'' does not match '^[a-zA-Z0-9]+$'
# 1    5c1a796d9011bd00153688c1  Task u'' does not match '^[a-zA-Z0-9]+$'
# 2    5c1a796e9011bd00133688e9
# 3    5c1a796e9011bd00133688ea
# 4    5c1a796e9011bd0014368996  Task u'' does not match '^[a-zA-Z0-9]+$'
# 5    5c1a796e9011bd00113688d6  Task u'' does not match '^[a-zA-Z0-9]+$'
# 7    5c1a796e9011bd00133688eb                                       NaN
# 10   5c1a796e9011bd00153688c5                                       NaN
# 11   5c1a7ee19011bd0011368aac  Task u'' does not match '^[a-zA-Z0-9]+$'
# 12   5c1a848d9011bd0014369702                                       NaN
# 37   5c1a80139011bd0014368e9c  Task u'' does not match '^[a-zA-Z0-9]+$'
# 38   5c1a80139011bd0015368c2d  Task u'' does not match '^[a-zA-Z0-9]+$'
# 40   5c1a80139011bd0014368e9f  Task u'' does not match '^[a-zA-Z0-9]+$'
# 41   5c1a80139011bd0013368cf2  Task u'' does not match '^[a-zA-Z0-9]+$'
# 43   5c1a80139011bd0014368ea3                                       NaN
# 90   5c1a7e169011bd0011368985  Task u'' does not match '^[a-zA-Z0-9]+$'
# 91   5c1a7e169011bd00133689d2  Task u'' does not match '^[a-zA-Z0-9]+$'
# 92   5c1a7e179011bd0015368995  Task u'' does not match '^[a-zA-Z0-9]+$'
# 93   5c1a7e179011bd0015368996  Task u'' does not match '^[a-zA-Z0-9]+$'
# 94   5c1a7e179011bd001536899a
# 100  5c1a7e179011bd00133689d3  Task u'' does not match '^[a-zA-Z0-9]+$'
# 101  5c1a7e179011bd0011368989  Task u'' does not match '^[a-zA-Z0-9]+$'
# 108  5c1a80899011bd0011368c81  Task u'' does not match '^[a-zA-Z0-9]+$'
#
#     ignore   template  valid
# 0    False  func_file  False
# 1    False  func_file  False
# 2    False  anat_file   True
# 3    False  anat_file   True
# 4    False  func_file  False
# 5    False  func_file  False
# 7      NaN        NaN    NaN
# 10     NaN        NaN    NaN
# 11   False  func_file  False
# 12     NaN        NaN    NaN
# 37   False  func_file  False
# 38   False  func_file  False
# 40   False  func_file  False
# 41   False  func_file  False
# 43     NaN        NaN    NaN
# 90   False  func_file  False
# 91   False  func_file  False
# 92   False  func_file  False
# 93   False  func_file  False
# 94   False  anat_file   True
# 100  False  func_file  False
# 101  False  func_file  False
# 108  False  func_file  False
#
# [23 rows x 22 columns]

# %% [markdown]
# So we've manipulated the data for a grouped view of Reward Effort scans. The next step is to map the group changes to the full spreadsheet.

# %%
modified_grouped = grouped_view.copy()
modified_flat = bids_classifications.copy()

# %%
# pandas.update works perfectly for this
modified_flat.update(modified_grouped)

# %%
modified_flat.loc[modified_flat['SeriesDescription'].str.contains("effort"),]
# Out:
#    Acq   Ce Custom Echo                                           Filename  \
# 37      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 38      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 40      NaN    NaN       sub-93274_ses-neff2_task-{file.info.BIDS.Task}...
# 90      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 91      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 92      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
# 93      NaN    NaN       sub-83835_ses-neff_task-{file.info.BIDS.Task}_...
#
#    Folder        Intent Measurement  Mod Modality  ...   RepetitionTime Run  \
# 37   func  [Functional]       [T2*]  NaN       MR  ...              3.0   2
# 38   func  [Functional]       [T2*]  NaN       MR  ...              0.5   3
# 40   func  [Functional]       [T2*]  NaN       MR  ...              3.0   1
# 90   func  [Functional]       [T2*]  NaN       MR  ...              3.0   3
# 91   func  [Functional]       [T2*]  NaN       MR  ...              3.0   4
# 92   func  [Functional]       [T2*]  NaN       MR  ...              3.0   2
# 93   func  [Functional]       [T2*]  NaN       MR  ...              3.0   1
#
#     SequenceName  SeriesDescription    Task            acquisition.id  \
# 37  _epfid2d1_64   ep2d_effort2_236  Effort  5c1a80139011bd0014368e9c
# 38   epfid2d1_64  ep2d_effort3_1416  Effort  5c1a80139011bd0015368c2d
# 40  _epfid2d1_64   ep2d_effort1_236  Effort  5c1a80139011bd0014368e9f
# 90  _epfid2d1_64   ep2d_effort3_168  Effort  5c1a7e169011bd0011368985
# 91  _epfid2d1_64   ep2d_effort4_168  Effort  5c1a7e169011bd00133689d2
# 92  _epfid2d1_64   ep2d_effort2_168  Effort  5c1a7e179011bd0015368995
# 93  _epfid2d1_64   ep2d_effort1_168  Effort  5c1a7e179011bd0015368996
#
#                                error_message ignore   template  valid
# 37  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 38  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 40  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 90  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 91  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 92  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
# 93  Task u'' does not match '^[a-zA-Z0-9]+$'  False  func_file  False
#
# [7 rows x 22 columns]

# %% [markdown]
# And as procedure, we can check if these changes are valid with the `upload_bids` tools

# %%
diff = upload_bids.get_unequal_cells(modified_flat, bids_classifications)

# %%
(modified_flat.applymap(type) == list).all()
# Out:
# Acq                  False
# Ce                   False
# Custom               False
# Echo                 False
# Filename             False
# Folder               False
# Intent                True
# Measurement          False
# Mod                  False
# Modality             False
# Path                 False
# Rec                  False
# RepetitionTime       False
# Run                  False
# SequenceName         False
# SeriesDescription    False
# Task                 False
# acquisition.id       False
# error_message        False
# ignore               False
# template             False
# valid                False
# dtype: bool

# %%
list_cols = (modified_flat.applymap(type) == list).all()
modified_flat.loc[:,list_cols].applymap(unlist_item)
# Out:
#          Intent
# 0    Functional
# 1    Functional
# 2    Structural
# 3    Structural
# 4    Functional
# 5    Functional
# 6    Structural
# 7     Localizer
# 8     Localizer
# 9     Localizer
# 10         Shim
# 11   Functional
# 12    Localizer
# 13    Localizer
# 14    Localizer
# 15   Functional
# 16   Functional
# 17   Functional
# 18   Structural
# 19   Structural
# 20   Functional
# 21   Structural
# 22         Shim
# 23    Localizer
# 24    Localizer
# 25    Localizer
# 26   Functional
# 27   Structural
# 28   Functional
# 29   Structural
# ..          ...
# 79   Functional
# 80   Functional
# 81   Functional
# 82   Structural
# 83   Structural
# 84   Functional
# 85   Structural
# 86         Shim
# 87    Localizer
# 88    Localizer
# 89    Localizer
# 90   Functional
# 91   Functional
# 92   Functional
# 93   Functional
# 94   Structural
# 95    Localizer
# 96    Localizer
# 97    Localizer
# 98   Functional
# 99   Functional
# 100  Functional
# 101  Functional
# 102  Functional
# 103  Structural
# 104   Localizer
# 105   Localizer
# 106   Localizer
# 107  Functional
# 108  Functional
#
# [109 rows x 1 columns]

# %%
upload_bids.validate_on_unequal_cells(diff, modified_flat)
# Out:
# The following changes don't seem to be valid for this data:
#
# Row 38, Column 14, "2"
# This field only accepts strings!
#
# Row 39, Column 14, "3"
# This field only accepts strings!
#
# Row 41, Column 14, "1"
# This field only accepts strings!
#
# Row 91, Column 14, "3"
# This field only accepts strings!
#
# Row 92, Column 14, "4"
# This field only accepts strings!
#
# Row 93, Column 14, "2"
# This field only accepts strings!
#
# Row 94, Column 14, "1"
# This field only accepts strings!
# False

# %% [markdown]
# We can wrap up the above processes in two new modules: `grouped_query` and `ungroup_query`, which respectively will wrap the grouping and ungrouping process.
