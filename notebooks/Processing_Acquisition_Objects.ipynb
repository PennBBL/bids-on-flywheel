# %% [markdown]
# # How to Process Acquisitions
#
# Here, using knowledge from our [bids querying notebook](./Querying_BIDS_Validity.ipynb) we demo how to process acquisitions

# %%
# modules
import flywheel
import pandas as pd
from pandas.io.json.normalize import nested_to_record
# add the script to the path
import sys
import os
sys.path.append(os.path.abspath("/Users/ttapera/Documents/BBL/Projects/bids-on-flywheel/flywheel_bids_tools/"))
import query_bids
from tqdm import tqdm
import math
import re

# %%
fw = flywheel.Client()

# %%
result = query_bids.query_fw("Q7 DSI", fw)
# Out:
# here
# Could not find a project in flywheel with that name!

# %%
view = fw.View(columns='subject')
subject_df = fw.read_view_dataframe(view, result.id)

sessions = []
view = fw.View(columns='acquisition')
pbar = tqdm(total=100)
for ind, row in subject_df.iterrows():
    session = fw.read_view_dataframe(view, row["subject.id"])
    if(session.shape[0] > 0):
        sessions.append(session)
    pbar.update(10)
pbar.close()

acquisitions = pd.concat(sessions)
# Out:
# 160it [00:00, 175.10it/s]

# %%
acquisitions.head()
# Out:
#              acquisition.id     acquisition.label acquisition.timestamp  \
# 0  5c8011f0df93e3002efeb11e             Localizer   2018-02-10 19:36:23
# 1  5c8011f0df93e3002efeb11f      t1w_mprage_0.9mm   2018-02-10 19:44:45
# 2  5c8011f0df93e3002efeb120       t2w_space_0.9mm   2018-02-10 19:50:24
# 3  5c8011f0df93e30029fce04e  DSI_730dir_b5000_mb3   2018-02-10 19:52:59
# 4  5c8011f0df93e3002bfcf5ee  restingBOLD_mb6_1200   2018-02-10 20:45:51
#
#   acquisition.timezone                project.id project.label  \
# 0     America/New_York  5c7d7616df93e30028fc5227        Q7 DSI
# 1     America/New_York  5c7d7616df93e30028fc5227        Q7 DSI
# 2     America/New_York  5c7d7616df93e30028fc5227        Q7 DSI
# 3     America/New_York  5c7d7616df93e30028fc5227        Q7 DSI
# 4     America/New_York  5c7d7616df93e30028fc5227        Q7 DSI
#
#                  session.id        session.label                subject.id  \
# 0  5c8011f0df93e3002efeb11c  2018-02-10 14:21:55  5c8011f0df93e3002dfd44b8
# 1  5c8011f0df93e3002efeb11c  2018-02-10 14:21:55  5c8011f0df93e3002dfd44b8
# 2  5c8011f0df93e3002efeb11c  2018-02-10 14:21:55  5c8011f0df93e3002dfd44b8
# 3  5c8011f0df93e3002efeb11c  2018-02-10 14:21:55  5c8011f0df93e3002dfd44b8
# 4  5c8011f0df93e3002efeb11c  2018-02-10 14:21:55  5c8011f0df93e3002dfd44b8
#
#                                       subject.label
# 0  18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044
# 1  18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044
# 2  18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044
# 3  18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044
# 4  18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044

# %% [markdown]
# First, fetch one of the files:

# %%
acquisition = fw.get("5c8011f0df93e3002efeb11e")
acquisition
# Out:
# {'analyses': [],
#  'collections': None,
#  'created': datetime.datetime(2019, 3, 6, 18, 31, 12, 422000, tzinfo=tzutc()),
#  'files': [{'classification': {'Intent': ['Localizer'], 'Measurement': ['T2']},
#             'created': datetime.datetime(2019, 3, 6, 18, 31, 14, 691000, tzinfo=tzutc()),
#             'hash': '',
#             'id': '97167590-f830-4300-9d96-fdec3ed47c67',
#             'info': {'AcquisitionDate': '20180210',
#                      'AcquisitionMatrix': [256, 0, 0, 192],
#                      'AcquisitionNumber': 1,
#                      'AcquisitionTime': '143615.282500',
#                      'AngioFlag': 'N',
#                      'BitsAllocated': 16,
#                      'BitsStored': 12,
#                      'BodyPartExamined': 'BRAIN',
#                      'Columns': 256,
#                      'ContentDate': '20180210',
#                      'ContentTime': '143623.607000',
#                      'DateOfLastCalibration': [20090304, 20090304],
#                      'DeviceSerialNumber': '66044',
#                      'EchoNumbers': 1,
#                      'EchoTime': 3,
#                      'EchoTrainLength': 1,
#                      'FlipAngle': 15,
#                      'FrameOfReferenceUID': '1.3.12.2.1107.5.2.43.66044.1.20180210143516705.0.0.0',
#                      'HighBit': 11,
#                      'ImageOrientationPatient': [1, 0, 0, 0, 1, 0],
#                      'ImagePositionPatient': [-150, -195, 0],
#                      'ImageType': ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM'],
#                      'ImagedNucleus': '1H',
#                      'ImagingFrequency': 123.255,
#                      'InPlanePhaseEncodingDirection': 'COL',
#                      'InstanceCreationDate': '20180210',
#                      'InstanceCreationTime': '143623.607000',
#                      'InstanceNumber': 3,
#                      'InstitutionAddress': 'Curie Blvd. '
#                                            '422,Philadelphia,PA,US,19104',
#                      'InstitutionName': 'SC3T',
#                      'LargestImagePixelValue': 362,
#                      'MRAcquisitionType': '2D',
#                      'MagneticFieldStrength': 3,
#                      'Manufacturer': 'SIEMENS',
#                      'ManufacturerModelName': 'Prisma',
#                      'Modality': 'MR',
#                      'NumberOfAverages': 1,
#                      'NumberOfFrames': 1,
#                      'NumberOfPhaseEncodingSteps': 192,
#                      'OperatorsName': 'RBetzel',
#                      'PatientAge': '026Y',
#                      'PatientBirthDate': '19910829',
#                      'PatientID': '18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044',
#                      'PatientName': '828062_HJK_123456',
#                      'PatientPosition': 'HFS',
#                      'PatientSex': 'F',
#                      'PatientSize': 1.7018,
#                      'PatientWeight': 63.5029,
#                      'PercentPhaseFieldOfView': 100,
#                      'PercentSampling': 75,
#                      'PerformedProcedureStepDescription': 'CAMRIS^Bassett',
#                      'PerformedProcedureStepID': 'MR20180210142155',
#                      'PerformedProcedureStepStartDate': '20180210',
#                      'PerformedProcedureStepStartTime': '142155.345000',
#                      'PerformingPhysicianName': 'DETRE',
#                      'PhotometricInterpretation': 'MONOCHROME2',
#                      'PhysiciansOfRecord': [],
#                      'PixelBandwidth': 260,
#                      'PixelRepresentation': 0,
#                      'PixelSpacing': [1, 1],
#                      'ProtocolName': 'Localizer',
#                      'ReferringPhysicianName': 'DETRE',
#                      'RepetitionTime': 40,
#                      'RequestedProcedureDescription': 'CAMRIS Bassett',
#                      'Rows': 256,
#                      'SAR': 0.00423588,
#                      'SOPClassUID': 'MR Image Storage',
#                      'SOPInstanceUID': '1.3.12.2.1107.5.2.43.66044.2018021014362352136752128',
#                      'SamplesPerPixel': 1,
#                      'ScanningSequence': 'GR',
#                      'SequenceName': '*fl2d1',
#                      'SequenceVariant': 'SP',
#                      'SeriesDate': '20180210',
#                      'SeriesDescription': 'Localizer',
#                      'SeriesInstanceUID': '1.3.12.2.1107.5.2.43.66044.2018021014361413384252115.0.0.0',
#                      'SeriesNumber': 1,
#                      'SeriesTime': '143623.595000',
#                      'SliceLocation': 0,
#                      'SliceThickness': 5,
#                      'SmallestImagePixelValue': 0,
#                      'SoftwareVersions': 'syngo MR D13D',
#                      'SpacingBetweenSlices': 6,
#                      'SpecificCharacterSet': 'ISO_IR 100',
#                      'StationName': 'AWP66044',
#                      'StudyDate': '20180210',
#                      'StudyDescription': 'CAMRIS^Bassett',
#                      'StudyID': '1',
#                      'StudyInstanceUID': '1.3.12.2.1107.5.2.43.66044.30000018020520321493800000091',
#                      'StudyTime': '142155.287000',
#                      'TimeOfLastCalibration': [123723.0, 123723.0],
#                      'TransmitCoilName': 'Body',
#                      'VariableFlipAngleFlag': 'N',
#                      'WindowCenter': 180,
#                      'WindowCenterWidthExplanation': 'Algo1',
#                      'WindowWidth': 423,
#                      'dBdt': 0},
#             'info_exists': None,
#             'mimetype': 'application/zip',
#             'modality': 'MR',
#             'modified': datetime.datetime(2019, 3, 6, 18, 31, 16, 743000, tzinfo=tzutc()),
#             'name': 'Localizer.dicom.zip',
#             'origin': {'id': 'arikahn@upenn.edu',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 224739,
#             'tags': [],
#             'type': 'dicom',
#             'zip_member_count': 3},
#            {'classification': {'Intent': ['Localizer'], 'Measurement': ['T2']},
#             'created': datetime.datetime(2019, 3, 6, 18, 31, 18, 487000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-c75827418a8b572894978779c2d91f0b739c5b2b9485162439fcf2cf64c38a84375e16abfbc542d01cf333d4f7c8b38c',
#             'id': 'dfa4b566-fab5-4c8f-b402-ffaabe51d529',
#             'info': {'AcquisitionDateTime': '2018-02-10T14:36:15.282500',
#                      'AcquisitionMatrixPE': 192,
#                      'AcquisitionNumber': 1,
#                      'AcquisitionTime': '14:36:15.282500',
#                      'BaseResolution': 256,
#                      'BodyPartExamined': 'BRAIN',
#                      'ConsistencyInfo': 'N4_VD13D_LATEST_20130810',
#                      'ConversionSoftware': 'dcm2niix',
#                      'ConversionSoftwareVersion': 'v1.0.20180918  '
#                                                   '(JP2:OpenJPEG) GCC4.8.4',
#                      'DeviceSerialNumber': '66044',
#                      'EchoTime': 0.003,
#                      'FlipAngle': 15,
#                      'ImageOrientationPatientDICOM': [1, 0, 0, 0, 1, 0],
#                      'ImageType': ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM'],
#                      'InPlanePhaseEncodingDirectionDICOM': 'COL',
#                      'InstitutionAddress': 'Curie_Blvd._422_Philadelphia_PA_US_19104',
#                      'InstitutionName': 'SC3T',
#                      'MRAcquisitionType': '2D',
#                      'MagneticFieldStrength': 3,
#                      'Manufacturer': 'Siemens',
#                      'ManufacturersModelName': 'Prisma',
#                      'Modality': 'MR',
#                      'PartialFourier': 1,
#                      'PatientID': '18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044',
#                      'PatientName': '828062_HJK_123456',
#                      'PatientPosition': 'HFS',
#                      'PatientSex': 'F',
#                      'PatientWeight': 63.5029,
#                      'PercentPhaseFOV': 100,
#                      'PhaseEncodingDirection': 'j-',
#                      'PhaseEncodingSteps': 192,
#                      'PhaseResolution': 0.75,
#                      'PixelBandwidth': 260,
#                      'ProcedureStepDescription': 'CAMRIS_Bassett',
#                      'ProtocolName': 'Localizer',
#                      'PulseSequenceDetails': '%SiemensSeq%_gre',
#                      'ReceiveCoilActiveElements': 'HC1-7',
#                      'ReceiveCoilName': 'HeadNeck_64',
#                      'ReconMatrixPE': 256,
#                      'ReferringPhysicianName': 'DETRE',
#                      'RepetitionTime': 0.04,
#                      'SAR': 0.00423588,
#                      'ScanningSequence': 'GR',
#                      'SequenceName': '_fl2d1',
#                      'SequenceVariant': 'SP',
#                      'SeriesDescription': 'Localizer',
#                      'SeriesInstanceUID': '1.3.12.2.1107.5.2.43.66044.2018021014361413384252115.0.0.0',
#                      'SeriesNumber': 1,
#                      'ShimSetting': [3812, 2730, 256, 60, -8, -7, -69, 23],
#                      'SliceThickness': 5,
#                      'SoftwareVersions': 'syngo_MR_D13D',
#                      'SpacingBetweenSlices': 6,
#                      'StationName': 'AWP66044',
#                      'StudyID': '1',
#                      'StudyInstanceUID': '1.3.12.2.1107.5.2.43.66044.30000018020520321493800000091',
#                      'TxRefAmp': 217.359},
#             'info_exists': None,
#             'mimetype': 'application/octet-stream',
#             'modality': 'MR',
#             'modified': datetime.datetime(2019, 3, 6, 18, 31, 17, 647000, tzinfo=tzutc()),
#             'name': 'Localizer_1_i00003.nii.gz',
#             'origin': {'id': '5c8011f4df93e3002cfdedf6',
#                        'method': None,
#                        'name': None,
#                        'type': 'job',
#                        'via': None},
#             'replaced': None,
#             'size': 43328,
#             'tags': [],
#             'type': 'nifti',
#             'zip_member_count': None},
#            {'classification': {'Intent': ['Localizer'], 'Measurement': ['T2']},
#             'created': datetime.datetime(2019, 3, 6, 18, 31, 18, 984000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-6a75e5b37205832c076d4ed910994df170f93750913ba5c1cd4b391115369b39a7780c3ec4440ed3b3ef83f40b1ea5c6',
#             'id': '790a3143-1e9b-47f9-9d52-feabf7efa048',
#             'info': {'AcquisitionDateTime': '2018-02-10T14:36:15.295000',
#                      'AcquisitionMatrixPE': 192,
#                      'AcquisitionNumber': 1,
#                      'AcquisitionTime': '14:36:15.295000',
#                      'BaseResolution': 256,
#                      'BodyPartExamined': 'BRAIN',
#                      'ConsistencyInfo': 'N4_VD13D_LATEST_20130810',
#                      'ConversionSoftware': 'dcm2niix',
#                      'ConversionSoftwareVersion': 'v1.0.20180918  '
#                                                   '(JP2:OpenJPEG) GCC4.8.4',
#                      'DeviceSerialNumber': '66044',
#                      'EchoTime': 0.003,
#                      'FlipAngle': 15,
#                      'ImageOrientationPatientDICOM': [1, 0, 0, 0, 0, -1],
#                      'ImageType': ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM'],
#                      'InPlanePhaseEncodingDirectionDICOM': 'ROW',
#                      'InstitutionAddress': 'Curie_Blvd._422_Philadelphia_PA_US_19104',
#                      'InstitutionName': 'SC3T',
#                      'MRAcquisitionType': '2D',
#                      'MagneticFieldStrength': 3,
#                      'Manufacturer': 'Siemens',
#                      'ManufacturersModelName': 'Prisma',
#                      'Modality': 'MR',
#                      'PartialFourier': 1,
#                      'PatientID': '18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044',
#                      'PatientName': '828062_HJK_123456',
#                      'PatientPosition': 'HFS',
#                      'PatientSex': 'F',
#                      'PatientWeight': 63.5029,
#                      'PercentPhaseFOV': 100,
#                      'PhaseEncodingDirection': 'i',
#                      'PhaseEncodingSteps': 192,
#                      'PhaseResolution': 0.75,
#                      'PixelBandwidth': 260,
#                      'ProcedureStepDescription': 'CAMRIS_Bassett',
#                      'ProtocolName': 'Localizer',
#                      'PulseSequenceDetails': '%SiemensSeq%_gre',
#                      'ReceiveCoilActiveElements': 'HC1-7',
#                      'ReceiveCoilName': 'HeadNeck_64',
#                      'ReconMatrixPE': 256,
#                      'ReferringPhysicianName': 'DETRE',
#                      'RepetitionTime': 0.04,
#                      'SAR': 0.00423588,
#                      'ScanningSequence': 'GR',
#                      'SequenceName': '_fl2d1',
#                      'SequenceVariant': 'SP',
#                      'SeriesDescription': 'Localizer',
#                      'SeriesInstanceUID': '1.3.12.2.1107.5.2.43.66044.2018021014361413384252115.0.0.0',
#                      'SeriesNumber': 1,
#                      'ShimSetting': [3812, 2730, 256, 60, -8, -7, -69, 23],
#                      'SliceThickness': 5,
#                      'SoftwareVersions': 'syngo_MR_D13D',
#                      'SpacingBetweenSlices': 6,
#                      'StationName': 'AWP66044',
#                      'StudyID': '1',
#                      'StudyInstanceUID': '1.3.12.2.1107.5.2.43.66044.30000018020520321493800000091',
#                      'TxRefAmp': 217.359},
#             'info_exists': None,
#             'mimetype': 'application/octet-stream',
#             'modality': 'MR',
#             'modified': datetime.datetime(2019, 3, 6, 18, 31, 17, 647000, tzinfo=tzutc()),
#             'name': 'Localizer_1_i00002.nii.gz',
#             'origin': {'id': '5c8011f4df93e3002cfdedf6',
#                        'method': None,
#                        'name': None,
#                        'type': 'job',
#                        'via': None},
#             'replaced': None,
#             'size': 41865,
#             'tags': [],
#             'type': 'nifti',
#             'zip_member_count': None},
#            {'classification': {'Intent': ['Localizer'], 'Measurement': ['T2']},
#             'created': datetime.datetime(2019, 3, 6, 18, 31, 19, 484000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-91222e457048c705abc69a556bd7676daa35c205ca7d39d1348ee014098856b745b2887952a9246ac55632b388de54c2',
#             'id': '96b050f5-709f-4368-81a4-2892ad9138fd',
#             'info': {'AcquisitionDateTime': '2018-02-10T14:36:15.267500',
#                      'AcquisitionMatrixPE': 192,
#                      'AcquisitionNumber': 1,
#                      'AcquisitionTime': '14:36:15.267500',
#                      'BaseResolution': 256,
#                      'BodyPartExamined': 'BRAIN',
#                      'ConsistencyInfo': 'N4_VD13D_LATEST_20130810',
#                      'ConversionSoftware': 'dcm2niix',
#                      'ConversionSoftwareVersion': 'v1.0.20180918  '
#                                                   '(JP2:OpenJPEG) GCC4.8.4',
#                      'DeviceSerialNumber': '66044',
#                      'EchoTime': 0.003,
#                      'FlipAngle': 15,
#                      'ImageOrientationPatientDICOM': [0, 1, 0, 0, 0, -1],
#                      'ImageType': ['ORIGINAL', 'PRIMARY', 'M', 'ND', 'NORM'],
#                      'InPlanePhaseEncodingDirectionDICOM': 'ROW',
#                      'InstitutionAddress': 'Curie_Blvd._422_Philadelphia_PA_US_19104',
#                      'InstitutionName': 'SC3T',
#                      'MRAcquisitionType': '2D',
#                      'MagneticFieldStrength': 3,
#                      'Manufacturer': 'Siemens',
#                      'ManufacturersModelName': 'Prisma',
#                      'Modality': 'MR',
#                      'PartialFourier': 1,
#                      'PatientID': '18.02.10-13:38:26-STD-1.3.12.2.1107.5.2.43.66044',
#                      'PatientName': '828062_HJK_123456',
#                      'PatientPosition': 'HFS',
#                      'PatientSex': 'F',
#                      'PatientWeight': 63.5029,
#                      'PercentPhaseFOV': 100,
#                      'PhaseEncodingDirection': 'i',
#                      'PhaseEncodingSteps': 192,
#                      'PhaseResolution': 0.75,
#                      'PixelBandwidth': 260,
#                      'ProcedureStepDescription': 'CAMRIS_Bassett',
#                      'ProtocolName': 'Localizer',
#                      'PulseSequenceDetails': '%SiemensSeq%_gre',
#                      'ReceiveCoilActiveElements': 'HC1-7',
#                      'ReceiveCoilName': 'HeadNeck_64',
#                      'ReconMatrixPE': 256,
#                      'ReferringPhysicianName': 'DETRE',
#                      'RepetitionTime': 0.04,
#                      'SAR': 0.00423588,
#                      'ScanningSequence': 'GR',
#                      'SequenceName': '_fl2d1',
#                      'SequenceVariant': 'SP',
#                      'SeriesDescription': 'Localizer',
#                      'SeriesInstanceUID': '1.3.12.2.1107.5.2.43.66044.2018021014361413384252115.0.0.0',
#                      'SeriesNumber': 1,
#                      'ShimSetting': [3812, 2730, 256, 60, -8, -7, -69, 23],
#                      'SliceThickness': 5,
#                      'SoftwareVersions': 'syngo_MR_D13D',
#                      'SpacingBetweenSlices': 6,
#                      'StationName': 'AWP66044',
#                      'StudyID': '1',
#                      'StudyInstanceUID': '1.3.12.2.1107.5.2.43.66044.30000018020520321493800000091',
#                      'TxRefAmp': 217.359},
#             'info_exists': None,
#             'mimetype': 'application/octet-stream',
#             'modality': 'MR',
#             'modified': datetime.datetime(2019, 3, 6, 18, 31, 17, 647000, tzinfo=tzutc()),
#             'name': 'Localizer_1_i00001.nii.gz',
#             'origin': {'id': '5c8011f4df93e3002cfdedf6',
#                        'method': None,
#                        'name': None,
#                        'type': 'job',
#                        'via': None},
#             'replaced': None,
#             'size': 49149,
#             'tags': [],
#             'type': 'nifti',
#             'zip_member_count': None}],
#  'id': '5c8011f0df93e3002efeb11e',
#  'info': {},
#  'info_exists': None,
#  'label': 'Localizer',
#  'modified': datetime.datetime(2019, 3, 6, 18, 31, 12, 422000, tzinfo=tzutc()),
#  'notes': [],
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'bbl',
#              'project': '5c7d7616df93e30028fc5227',
#              'session': '5c8011f0df93e3002efeb11c',
#              'subject': '5c8011f0df93e3002dfd44b8'},
#  'permissions': [{'access': 'rw', 'id': 'tinashemtapera@gmail.com'}],
#  'public': None,
#  'session': '5c8011f0df93e3002efeb11c',
#  'tags': [],
#  'timestamp': datetime.datetime(2018, 2, 10, 19, 36, 23, tzinfo=tzutc()),
#  'timezone': 'America/New_York',
#  'uid': '1312211075243660442018021014361413384252115000'}

# %% [markdown]
# Then, convert the file object to dictionary and flatten with `pandas.io.json`:

# %%
files = [x.to_dict() for x in acquisition.files]

# %%
from pandas.io.json.normalize import nested_to_record

flat_files = [nested_to_record(my_dict, sep='_') for my_dict in files]

# %% [markdown]
# Keep the acquisition ID:

# %%
for x in flat_files:
    x.update( {'acquisition.id': acquisition.id})

# %% [markdown]
# Now, filter out the keys in the flattened dictionary using regex:

# %%
string = 'classification'


flat_files = [{k:v for k,v in x.items() if re.match(string, k)} for x in flat_files]

# %%
flat_files[0]
# Out:
# {'classification_Intent': ['Localizer'], 'classification_Measurement': ['T2']}

# %% [markdown]
# As a function, this looks like:

# %%
def unlist_item(ls):
    
    if type(ls) is list:
        ls.sort()
        return(', '.join(x for x in ls))
    else:
        return float('nan')

def process_acquisition(acq_id):
    
    acq = fw.get(acq_id)
    files = [x.to_dict() for x in acq.files]
    flat_files = [nested_to_record(my_dict, sep='_') for my_dict in files]
    cols = r'(classification)|(^type$)|(^modality$)|(BIDS)|(RepetitionTime)|(SequenceName)|(SeriesDescription)'
    flat_files = [{k:v for k,v in my_dict.items() if re.search(cols, k)} for my_dict in flat_files]
    for x in flat_files:
        x.update( {'acquisition.id': acquisition.id})
    df = pd.DataFrame(flat_files)
    list_cols = (df.applymap(type) == list).all()
    df.loc[:,list_cols] = df.loc[:,list_cols].applymap(unlist_item)
    return df

# %%
acq1 = process_acquisition("5c8011f0df93e3002efeb11e")
acq1
# Out:
#              acquisition.id classification_Intent classification_Measurement  \
# 0  5c8011f0df93e3002efeb11e             Localizer                         T2
# 1  5c8011f0df93e3002efeb11e             Localizer                         T2
# 2  5c8011f0df93e3002efeb11e             Localizer                         T2
# 3  5c8011f0df93e3002efeb11e             Localizer                         T2
#
#    info_RepetitionTime info_SequenceName info_SeriesDescription modality  \
# 0                40.00            *fl2d1              Localizer       MR
# 1                 0.04            _fl2d1              Localizer       MR
# 2                 0.04            _fl2d1              Localizer       MR
# 3                 0.04            _fl2d1              Localizer       MR
#
#     type
# 0  dicom
# 1  nifti
# 2  nifti
# 3  nifti

# %%
acq2 = process_acquisition("5c8011f0df93e3002efeb120")
acq2
# Out:
#              acquisition.id classification_Intent classification_Measurement  \
# 0  5c8011f0df93e3002efeb11e            Structural                         T2
# 1  5c8011f0df93e3002efeb11e            Structural                         T2
#
#    info_RepetitionTime info_SequenceName info_SeriesDescription modality  \
# 0               3200.0        *spc_314ns        t2w_space_0.9mm       MR
# 1                  3.2        _spc_314ns        t2w_space_0.9mm       MR
#
#     type
# 0  dicom
# 1  nifti

# %%
pd.concat([acq1, acq2], ignore_index=True)
# Out:
#              acquisition.id classification_Intent classification_Measurement  \
# 0  5c8011f0df93e3002efeb11e             Localizer                         T2
# 1  5c8011f0df93e3002efeb11e             Localizer                         T2
# 2  5c8011f0df93e3002efeb11e             Localizer                         T2
# 3  5c8011f0df93e3002efeb11e             Localizer                         T2
# 4  5c8011f0df93e3002efeb11e            Structural                         T2
# 5  5c8011f0df93e3002efeb11e            Structural                         T2
#
#    info_RepetitionTime info_SequenceName info_SeriesDescription modality  \
# 0                40.00            *fl2d1              Localizer       MR
# 1                 0.04            _fl2d1              Localizer       MR
# 2                 0.04            _fl2d1              Localizer       MR
# 3                 0.04            _fl2d1              Localizer       MR
# 4              3200.00        *spc_314ns        t2w_space_0.9mm       MR
# 5                 3.20        _spc_314ns        t2w_space_0.9mm       MR
#
#     type
# 0  dicom
# 1  nifti
# 2  nifti
# 3  nifti
# 4  dicom
# 5  nifti

# %%
# %%time
acq_dfs = []
#temp = acquisitions.sample(n=100)
for index, row in acquisitions.iterrows():
    
    try:
        temp = process_acquisition(row["acquisition.id"])
        acq_dfs.append(temp)
    except:
        continue
# Out:
# CPU times: user 1.24 s, sys: 12 ms, total: 1.25 s
# Wall time: 4.51 s

# %%
pd.concat(acq_dfs).head()
# Out:
# /data/joy/BBL/applications/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#              acquisition.id classification_Intent classification_Measurement  \
# 0  5c8011f0df93e3002efeb11e             Localizer                         T2
# 1  5c8011f0df93e3002efeb11e             Localizer                         T2
# 2  5c8011f0df93e3002efeb11e             Localizer                         T2
# 3  5c8011f0df93e3002efeb11e             Localizer                         T2
# 0  5c8011f0df93e3002efeb11e            Structural                         T1
#
#    info_RepetitionTime info_SequenceName info_SeriesDescription modality  \
# 0                40.00            *fl2d1              Localizer       MR
# 1                 0.04            _fl2d1              Localizer       MR
# 2                 0.04            _fl2d1              Localizer       MR
# 3                 0.04            _fl2d1              Localizer       MR
# 0              2500.00      *tfl3d1_16ns       t1w_mprage_0.9mm       MR
#
#     type
# 0  dicom
# 1  nifti
# 2  nifti
# 3  nifti
# 0  dicom

# %%
grouped_data = bids_data2.groupby(groups_list, as_index=False).nth(1).reset_index(drop=True)

# %%
grouped_data
# Out:
#              acquisition.id classification_Intent classification_Measurement  \
# 0  5c8011f0df93e3002efeb11e             Localizer                         T2
# 1  5c8011f0df93e3002efeb11e            Structural                         T1
# 2  5c8011f0df93e3002efeb11e            Structural                         T2
# 3  5c8011f0df93e3002efeb11e            Functional                        T2*
# 4  5c8011f0df93e3002efeb11e                   NaN                        NaN
#
#    info_RepetitionTime info_SequenceName info_SeriesDescription modality  \
# 0                 0.04            _fl2d1              Localizer       MR
# 1                 2.50      _tfl3d1_16ns       t1w_mprage_0.9mm       MR
# 2                 3.20        _spc_314ns        t2w_space_0.9mm       MR
# 3                 0.50       epfid2d1_64   restingBOLD_mb6_1200       MR
# 4              4300.00      ep_b3735#487   DSI_730dir_b5000_mb3       MR
#
#     type  group_id
# 0  nifti         2
# 1  nifti         3
# 2  nifti         4
# 3  nifti         1
# 4  dicom         0

# %%
grouped_data_modified = grouped_data.copy()
grouped_data_modified.loc[grouped_data_modified['classification_Measurement'].isnull(), 'classification_Measurement'] = "Diffusion"

# %%
grouped_data_modified
# Out:
#              acquisition.id classification_Intent classification_Measurement  \
# 0  5c8011f0df93e3002efeb11e             Localizer                         T2
# 1  5c8011f0df93e3002efeb11e            Structural                         T1
# 2  5c8011f0df93e3002efeb11e            Structural                         T2
# 3  5c8011f0df93e3002efeb11e            Functional                        T2*
# 4  5c8011f0df93e3002efeb11e                   NaN                  Diffusion
#
#    info_RepetitionTime info_SequenceName info_SeriesDescription modality  \
# 0                 0.04            _fl2d1              Localizer       MR
# 1                 2.50      _tfl3d1_16ns       t1w_mprage_0.9mm       MR
# 2                 3.20        _spc_314ns        t2w_space_0.9mm       MR
# 3                 0.50       epfid2d1_64   restingBOLD_mb6_1200       MR
# 4              4300.00      ep_b3735#487   DSI_730dir_b5000_mb3       MR
#
#     type  group_id
# 0  nifti         2
# 1  nifti         3
# 2  nifti         4
# 3  nifti         1
# 4  dicom         0

# %%
diff = upload_bids.get_unequal_cells(grouped_data_modified, grouped_data)
diff
# Out:
# [[4, 2]]

# %%
changes = {}

for x in diff:
    
    key = grouped_data_modified.loc[x[0], 'group_id']
    val = (grouped_data_modified.columns[x[1]], grouped_data_modified.iloc[x[0], x[1]])
    changes.update({key: val})

# %%
changes
# Out:
# {0: ('classification_Measurement', 'Diffusion')}

# %%
for group, change in changes.items():
    
    bids_data2.loc[bids_data2['group_id'] == group, change[0]] = change[1]

# %%
bids_data2
# Out:
#                acquisition.id classification_Intent  \
# 0    5c8011f0df93e3002efeb11e             Localizer
# 1    5c8011f0df93e3002efeb11e             Localizer
# 2    5c8011f0df93e3002efeb11e             Localizer
# 3    5c8011f0df93e3002efeb11e             Localizer
# 4    5c8011f0df93e3002efeb11e            Structural
# 5    5c8011f0df93e3002efeb11e            Structural
# 6    5c8011f0df93e3002efeb11e            Structural
# 7    5c8011f0df93e3002efeb11e            Structural
# 8    5c8011f0df93e3002efeb11e                   NaN
# 9    5c8011f0df93e3002efeb11e            Functional
# 10   5c8011f0df93e3002efeb11e            Functional
# 11   5c8011f0df93e3002efeb11e             Localizer
# 12   5c8011f0df93e3002efeb11e             Localizer
# 13   5c8011f0df93e3002efeb11e             Localizer
# 14   5c8011f0df93e3002efeb11e             Localizer
# 15   5c8011f0df93e3002efeb11e            Structural
# 16   5c8011f0df93e3002efeb11e            Structural
# 17   5c8011f0df93e3002efeb11e            Structural
# 18   5c8011f0df93e3002efeb11e            Structural
# 19   5c8011f0df93e3002efeb11e                   NaN
# 20   5c8011f0df93e3002efeb11e            Functional
# 21   5c8011f0df93e3002efeb11e            Functional
# 22   5c8011f0df93e3002efeb11e             Localizer
# 23   5c8011f0df93e3002efeb11e             Localizer
# 24   5c8011f0df93e3002efeb11e             Localizer
# 25   5c8011f0df93e3002efeb11e             Localizer
# 26   5c8011f0df93e3002efeb11e            Structural
# 27   5c8011f0df93e3002efeb11e            Structural
# 28   5c8011f0df93e3002efeb11e            Structural
# 29   5c8011f0df93e3002efeb11e            Structural
# ..                        ...                   ...
# 145  5c8011f0df93e3002efeb11e            Structural
# 146  5c8011f0df93e3002efeb11e                   NaN
# 147  5c8011f0df93e3002efeb11e            Functional
# 148  5c8011f0df93e3002efeb11e            Functional
# 149  5c8011f0df93e3002efeb11e             Localizer
# 150  5c8011f0df93e3002efeb11e             Localizer
# 151  5c8011f0df93e3002efeb11e             Localizer
# 152  5c8011f0df93e3002efeb11e             Localizer
# 153  5c8011f0df93e3002efeb11e            Structural
# 154  5c8011f0df93e3002efeb11e            Structural
# 155  5c8011f0df93e3002efeb11e            Structural
# 156  5c8011f0df93e3002efeb11e            Structural
# 157  5c8011f0df93e3002efeb11e            Functional
# 158  5c8011f0df93e3002efeb11e            Functional
# 159  5c8011f0df93e3002efeb11e             Localizer
# 160  5c8011f0df93e3002efeb11e             Localizer
# 161  5c8011f0df93e3002efeb11e             Localizer
# 162  5c8011f0df93e3002efeb11e             Localizer
# 163  5c8011f0df93e3002efeb11e            Structural
# 164  5c8011f0df93e3002efeb11e            Structural
# 165  5c8011f0df93e3002efeb11e            Structural
# 166  5c8011f0df93e3002efeb11e            Structural
# 167  5c8011f0df93e3002efeb11e                   NaN
# 168  5c8011f0df93e3002efeb11e                   NaN
# 169  5c8011f0df93e3002efeb11e            Functional
# 170  5c8011f0df93e3002efeb11e            Functional
# 171  5c8011f0df93e3002efeb11e             Localizer
# 172  5c8011f0df93e3002efeb11e             Localizer
# 173  5c8011f0df93e3002efeb11e             Localizer
# 174  5c8011f0df93e3002efeb11e             Localizer
#
#     classification_Measurement  info_RepetitionTime info_SequenceName  \
# 0                           T2                40.00            *fl2d1
# 1                           T2                 0.04            _fl2d1
# 2                           T2                 0.04            _fl2d1
# 3                           T2                 0.04            _fl2d1
# 4                           T1              2500.00      *tfl3d1_16ns
# 5                           T1                 2.50      _tfl3d1_16ns
# 6                           T2              3200.00        *spc_314ns
# 7                           T2                 3.20        _spc_314ns
# 8                    Diffusion              4300.00        ep_b610#41
# 9                          T2*               500.00       epfid2d1_64
# 10                         T2*                 0.50       epfid2d1_64
# 11                          T2                40.00            *fl2d1
# 12                          T2                 0.04            _fl2d1
# 13                          T2                 0.04            _fl2d1
# 14                          T2                 0.04            _fl2d1
# 15                          T1              2500.00      *tfl3d1_16ns
# 16                          T1                 2.50      _tfl3d1_16ns
# 17                          T2              3200.00        *spc_314ns
# 18                          T2                 3.20        _spc_314ns
# 19                   Diffusion              4300.00      ep_b3735#487
# 20                         T2*               500.00       epfid2d1_64
# 21                         T2*                 0.50       epfid2d1_64
# 22                          T2                40.00            *fl2d1
# 23                          T2                 0.04            _fl2d1
# 24                          T2                 0.04            _fl2d1
# 25                          T2                 0.04            _fl2d1
# 26                          T1              2500.00      *tfl3d1_16ns
# 27                          T1                 2.50      _tfl3d1_16ns
# 28                          T2              3200.00        *spc_314ns
# 29                          T2                 3.20        _spc_314ns
# ..                         ...                  ...               ...
# 145                         T2                 3.20        _spc_314ns
# 146                  Diffusion              4300.00      ep_b2940#334
# 147                        T2*               500.00       epfid2d1_64
# 148                        T2*                 0.50       epfid2d1_64
# 149                         T2                40.00            *fl2d1
# 150                         T2                 0.04            _fl2d1
# 151                         T2                 0.04            _fl2d1
# 152                         T2                 0.04            _fl2d1
# 153                         T1              2500.00      *tfl3d1_16ns
# 154                         T1                 2.50      _tfl3d1_16ns
# 155                         T2              3200.00        *spc_314ns
# 156                         T2                 3.20        _spc_314ns
# 157                        T2*               500.00       epfid2d1_64
# 158                        T2*                 0.50       epfid2d1_64
# 159                         T2                40.00            *fl2d1
# 160                         T2                 0.04            _fl2d1
# 161                         T2                 0.04            _fl2d1
# 162                         T2                 0.04            _fl2d1
# 163                         T1              2500.00      *tfl3d1_16ns
# 164                         T1                 2.50      _tfl3d1_16ns
# 165                         T2              3200.00        *spc_314ns
# 166                         T2                 3.20        _spc_314ns
# 167                  Diffusion              4300.00      ep_b2430#241
# 168                  Diffusion                 4.30             ep_b0
# 169                        T2*               500.00       epfid2d1_64
# 170                        T2*                 0.50       epfid2d1_64
# 171                         T2                40.00            *fl2d1
# 172                         T2                 0.04            _fl2d1
# 173                         T2                 0.04            _fl2d1
# 174                         T2                 0.04            _fl2d1
#
#     info_SeriesDescription modality   type  group_id
# 0                Localizer       MR  dicom         2
# 1                Localizer       MR  nifti         2
# 2                Localizer       MR  nifti         2
# 3                Localizer       MR  nifti         2
# 4         t1w_mprage_0.9mm       MR  dicom         3
# 5         t1w_mprage_0.9mm       MR  nifti         3
# 6          t2w_space_0.9mm       MR  dicom         4
# 7          t2w_space_0.9mm       MR  nifti         4
# 8     DSI_730dir_b5000_mb3       MR  dicom         0
# 9     restingBOLD_mb6_1200       MR  dicom         1
# 10    restingBOLD_mb6_1200       MR  nifti         1
# 11               Localizer       MR  dicom         2
# 12               Localizer       MR  nifti         2
# 13               Localizer       MR  nifti         2
# 14               Localizer       MR  nifti         2
# 15        t1w_mprage_0.9mm       MR  dicom         3
# 16        t1w_mprage_0.9mm       MR  nifti         3
# 17         t2w_space_0.9mm       MR  dicom         4
# 18         t2w_space_0.9mm       MR  nifti         4
# 19    DSI_730dir_b5000_mb3       MR  dicom         0
# 20    restingBOLD_mb6_1200       MR  dicom         1
# 21    restingBOLD_mb6_1200       MR  nifti         1
# 22               Localizer       MR  dicom         2
# 23               Localizer       MR  nifti         2
# 24               Localizer       MR  nifti         2
# 25               Localizer       MR  nifti         2
# 26        t1w_mprage_0.9mm       MR  dicom         3
# 27        t1w_mprage_0.9mm       MR  nifti         3
# 28         t2w_space_0.9mm       MR  dicom         4
# 29         t2w_space_0.9mm       MR  nifti         4
# ..                     ...      ...    ...       ...
# 145        t2w_space_0.9mm       MR  nifti         4
# 146   DSI_730dir_b5000_mb3       MR  dicom         0
# 147   restingBOLD_mb6_1200       MR  dicom         1
# 148   restingBOLD_mb6_1200       MR  nifti         1
# 149              Localizer       MR  dicom         2
# 150              Localizer       MR  nifti         2
# 151              Localizer       MR  nifti         2
# 152              Localizer       MR  nifti         2
# 153       t1w_mprage_0.9mm       MR  dicom         3
# 154       t1w_mprage_0.9mm       MR  nifti         3
# 155        t2w_space_0.9mm       MR  dicom         4
# 156        t2w_space_0.9mm       MR  nifti         4
# 157   restingBOLD_mb6_1200       MR  dicom         1
# 158   restingBOLD_mb6_1200       MR  nifti         1
# 159              Localizer       MR  dicom         2
# 160              Localizer       MR  nifti         2
# 161              Localizer       MR  nifti         2
# 162              Localizer       MR  nifti         2
# 163       t1w_mprage_0.9mm       MR  dicom         3
# 164       t1w_mprage_0.9mm       MR  nifti         3
# 165        t2w_space_0.9mm       MR  dicom         4
# 166        t2w_space_0.9mm       MR  nifti         4
# 167   DSI_730dir_b5000_mb3       MR  dicom         0
# 168   DSI_730dir_b5000_mb3       MR  nifti         0
# 169   restingBOLD_mb6_1200       MR  dicom         1
# 170   restingBOLD_mb6_1200       MR  nifti         1
# 171              Localizer       MR  dicom         2
# 172              Localizer       MR  nifti         2
# 173              Localizer       MR  nifti         2
# 174              Localizer       MR  nifti         2
#
# [175 rows x 9 columns]
