# %% [markdown]
# # Making sure your data is BIDS-compliant on Flywheel
#
# BIDS compliance is absolutely necessary for running many pre-processing pipelines on your data. Having correct metadata ensures that the pre-processing correctly handles your data. Incorrect BIDS naming can result in difficult-to-debug errors.
#
# For these reasons, we cover in-depth how to make sure your data is BIDS-compliant.
#
# First, let's look at an example subject.
#
# <img src="../images/initial_bids_error.png" alt="drawing" width="600"/>
#
# These red flags mean that there are errors converting the images to a BIDS-compliant name. Here you have two options
#
#   1. Click the "Info" button on the scan and make sure the BIDS section is completed correctly
#   2. Use the Flywheel API to change the BIDS properties
#
#
# ## The Flywheel data model
#
# Flywheel stores zip archives of the dicom data and nifti files. The names of the nifti files are usually determined by `dcm2niix` and that name sticks with the file for the rest of its life. I believe these files are managed using MongoDB's GridFS framework, so there are some non-intuitive things that can happen.
#
#   - More than one file can exist with the exact same name. The files are indexed by a BSON id, which is
#     unique for each file. The field containing the file name is not necessarily unique.
#
#   - Unless the data was uploaded in BIDS format, the actual BIDS-named data does not exist in Flywheel.
#     Instead, when a job needs requires BIDS input, the job uses the Flywheel API to download and rename
#     the data to be BIDS compliant.
#
#     - The renaming and JSON Sidecar creation uses information stored in Flywheel's MongoDB. Therefore to
#       change the BIDS filename, you simply update the files Document/BSON and next time a gear is run,
#       this new metadata will be used to create the BIDS directory.
#
# The metadata associated with each file can be edited through the Flywheel web interface or through the API. The web interface is not complete and still a little buggy (i.e. not all UI's contain BIDS fields). The SDK is fairly complete and documented, so that will be the focus of this notebook.
#
#
# ## Editing BIDS info from the web interface
#
# You can change the information on your scans by clicking the info icon in the file's row.
#
# <img src="../images/select_info.png" alt="drawing" width="600"/>
#
#
# The fields can then be edited manually. This is the initial interface presented:
#
# <img src="../images/basic_file_info.png" alt="drawing" width="600"/>
#
# where basic options about the contents of the file are editable. This will always be available when clicking the Info button. If the `BIDS Curation` gear has been run, you can scroll down and see the BIDS fields:
#
# <img src="../images/bids_info.png" alt="drawing" width="600"/>
#
# It is unclear to me if the `BIDS Curation` gear needs to be re-run for these changes to be committed to MongoDB.
#
# ## Editing BIDS Info Using the API
#
# The remainder of this document is a deep dive into how to access the BIDS data using the Flywheel SDK, which can be installed from PyPI using
#
# ```bash
#
# pip install flywheel-sdk
#
# ```
#
# The documentation for this package can be found [here](https://flywheel-io.github.io/core/branches/master/python/index.html).

# %%
import flywheel

# Create client
fw = flywheel.Client()

# %% [markdown]
# ## Logging In to Flywheel
#
# Note the documentation is out of date and the constructor for `flywheel.Client` does not take any arguments. Instead you have to login with your API key using the commandline `fw login`. Verify that your login worked and you can retrieve data from Flywheel:

# %%
fw.get_current_user()['email']
# Out:
# 'tinashemtapera@gmail.com'

# %% [markdown]
# ## The Basic Data Model
#
# Everything in flywheel is a *container*. >>>
#
# <img src="../images/data-model.png" alt="drawing" width="600"/>
#
# When you access a container, you can either do so as a method attribute, or a function. With a method, you implement a flywheel finder which indexes the data but doesn't quite return anything to you yet. As a function, the returned object usually is a dictionary (or list of dictionaries).
#
# For example, we can see the currently available project containers with the following command:

# %%
# the function
fw.projects()
# Out:
# [{'analyses': None,
#   'created': datetime.datetime(2018, 12, 13, 18, 23, 41, 986000, tzinfo=tzutc()),
#   'description': None,
#   'files': [],
#   'group': 'mcieslak',
#   'id': '5c12a3ad9011bd0013368726',
#   'info': {},
#   'info_exists': False,
#   'label': 'BBLTest',
#   'modified': datetime.datetime(2019, 2, 7, 17, 39, 35, 998000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': None,
#               'session': None,
#               'subject': None},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'tags': [],
#   'template': None}, {'analyses': None,
#   'created': datetime.datetime(2018, 12, 19, 15, 21, 10, 217000, tzinfo=tzutc()),
#   'description': None,
#   'files': [{'classification': {},
#              'created': datetime.datetime(2019, 1, 9, 19, 48, 52, 13000, tzinfo=tzutc()),
#              'hash': 'v0-sha384-1c77469675dad45012de0cbf1da5053e27918713ad822de64502a711d0238e56bc7b3f94946ba1e8d1921d1c8d68d1d4',
#              'id': '66463c4e-c46b-4975-868d-fb48c45039e8',
#              'info': {u'BIDS': {u'Filename': u'',
#                                 u'Folder': u'',
#                                 u'Path': u'',
#                                 u'error_message': u"Filename u'' is too short",
#                                 u'ignore': False,
#                                 u'template': u'project_file',
#                                 u'valid': False}},
#              'info_exists': True,
#              'mimetype': 'text/plain',
#              'modality': None,
#              'modified': datetime.datetime(2019, 1, 9, 22, 38, 19, 579000, tzinfo=tzutc()),
#              'name': 'freesurferlicese.txt',
#              'origin': {'id': 'azeez.adebimpe5@gmail.com',
#                         'method': None,
#                         'name': None,
#                         'type': 'user',
#                         'via': None},
#              'replaced': None,
#              'size': 62,
#              'tags': [],
#              'type': 'text',
#              'zip_member_count': None}],
#   'group': 'mcieslak',
#   'id': '5c1a61e69011bd0011368884',
#   'info': {u'BIDS': {u'Acknowledgements': u'',
#                      u'Authors': [],
#                      u'BIDSVersion': u'1.0.2',
#                      u'DatasetDOI': u'',
#                      u'Funding': u'',
#                      u'HowToAcknowledge': u'',
#                      u'License': u'',
#                      u'Name': u'Reward2018',
#                      u'ReferencesAndLinks': [],
#                      u'template': u'project'}},
#   'info_exists': True,
#   'label': 'Reward2018',
#   'modified': datetime.datetime(2019, 2, 12, 16, 8, 59, 700000, tzinfo=tzutc()),
#   'notes': [],
#   'parents': {'acquisition': None,
#               'analysis': None,
#               'group': 'mcieslak',
#               'project': None,
#               'session': None,
#               'subject': None},
#   'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#   'public': None,
#   'tags': [],
#   'template': None}]

# %%
# the indexer
fw.projects

# %% [markdown]
# ## Searching the Data
#
# The indexer itself has some common search methods such as `find()` and `find_first()`.

# %%
project = fw.projects.find_first('label=Reward2018')
print(project)
# Out:
# {'analyses': None,
#  'created': datetime.datetime(2018, 12, 19, 15, 21, 10, 217000, tzinfo=tzutc()),
#  'description': None,
#  'files': [{'classification': {},
#             'created': datetime.datetime(2019, 1, 9, 19, 48, 52, 13000, tzinfo=tzutc()),
#             'hash': 'v0-sha384-1c77469675dad45012de0cbf1da5053e27918713ad822de64502a711d0238e56bc7b3f94946ba1e8d1921d1c8d68d1d4',
#             'id': '66463c4e-c46b-4975-868d-fb48c45039e8',
#             'info': {u'BIDS': {u'Filename': u'',
#                                u'Folder': u'',
#                                u'Path': u'',
#                                u'error_message': u"Filename u'' is too short",
#                                u'ignore': False,
#                                u'template': u'project_file',
#                                u'valid': False}},
#             'info_exists': True,
#             'mimetype': 'text/plain',
#             'modality': None,
#             'modified': datetime.datetime(2019, 1, 9, 22, 38, 19, 579000, tzinfo=tzutc()),
#             'name': 'freesurferlicese.txt',
#             'origin': {'id': 'azeez.adebimpe5@gmail.com',
#                        'method': None,
#                        'name': None,
#                        'type': 'user',
#                        'via': None},
#             'replaced': None,
#             'size': 62,
#             'tags': [],
#             'type': 'text',
#             'zip_member_count': None}],
#  'group': 'mcieslak',
#  'id': '5c1a61e69011bd0011368884',
#  'info': {u'BIDS': {u'Acknowledgements': u'',
#                     u'Authors': [],
#                     u'BIDSVersion': u'1.0.2',
#                     u'DatasetDOI': u'',
#                     u'Funding': u'',
#                     u'HowToAcknowledge': u'',
#                     u'License': u'',
#                     u'Name': u'Reward2018',
#                     u'ReferencesAndLinks': [],
#                     u'template': u'project'}},
#  'info_exists': True,
#  'label': 'Reward2018',
#  'modified': datetime.datetime(2019, 2, 12, 16, 8, 59, 700000, tzinfo=tzutc()),
#  'notes': [],
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'mcieslak',
#              'project': None,
#              'session': None,
#              'subject': None},
#  'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#  'public': None,
#  'tags': [],
#  'template': None}

# %% [markdown]
# Once you can find a container by label, use the BSON id to extract its other key-value pairs. You'll notice that there is an `'_id'` field in all of these documents. This is the BSON id that is used to identify files in flywheel. Everything - files, subjects, sessions, analyses - has one of these that can be used for direct access. Confusingly, you can't access it directly with `project['id']`: you'll need to use `project['_id']`.

# %%
project['_id']
# Out:
# '5c1a61e69011bd0011368884'

# %% [markdown]
# In MongoDB, containers don't have to be accessed in order. For example, we can pull the subjects out of the project here:

# %%
for subject in project.subjects():
        print('%s: %s' % (subject.id, subject.label))
# Out:
# 5c352b991de80b0024480dda: 10180
# 5c352a081de80b0024480dcc: 102102
# 5c3535641de80b0024480e41: 104059
# 5c3527fe1de80b0024480db7: 10410
# 5c3541301de80b0024480ebc: 105168
# 5c353ab01de80b00198acafb: 105272
# 5c3542de1de80b00198acb34: 105490
# 5c35186f1de80b00198ac9f9: 105634
# 5c3539ea1de80b001c0da9c8: 106573
# 5c353e151de80b0024480ea0: 107055
# 5c3545391de80b00198acb42: 109741
# 5c3511cd1de80b0024480c9f: 11010
# 5c3532511de80b0024480e26: 11176
# 5c351c2f1de80b00156d3d76: 11186
#  'info_exists': True,
#  'label': 'day2',
#  'modified': datetime.datetime(2018, 12, 19, 17, 55, 51, 723000, tzinfo=tzutc()),
#  'notes': [],
#  'operator': 'TK',
#  'parents': {'acquisition': None,
#              'analysis': None,
#              'group': 'mcieslak',
#              'project': '5c1a61e69011bd0011368884',
#              'session': None,
#              'subject': '5c1a7e269011bd0011368994'},
#  'permissions': [{'access': 'admin', 'id': 'tinashemtapera@gmail.com'}],
#  'project': '5c1a61e69011bd0011368884',
#  'project_has_template': None,
#  'public': None,
#  'satisfies_template': None,
#  'subject': {'age': None,
#              'analyses': None,
#              'code': '17378',
#              'cohort': None,
#              'created': datetime.datetime(2018, 12, 19, 17, 21, 42, tzinfo=tzutc()),
#              'ethnicity': None,
#              'files': None,
#              'firstname': None,
#              'id': '5c1a7e269011bd0011368994',
#              'info': {},
#              'info_exists': False,
#              'label': '17378',
#              'lastname': None,
#              'modified': datetime.datetime(2018, 12, 28, 16, 54, 0, 396000, tzinfo=tzutc()),
#              'notes': None,
#              'parents': {'acquisition': None,
#                          'analysis': None,
#                          'group': 'mcieslak',
#                          'project': '5c1a61e69011bd0011368884',
#                          'session': None,
#                          'subject': None},
#              'permissions': [{'access': 'admin',
#                               'id': 'thadbrown@flywheel.io'},
#                              {'access': 'admin',
#                               'id': 'mattcieslak@gmail.com'},
#                              {'access': 'admin',
#                               'id': 'azeez.adebimpe5@gmail.com'},
#                              {'access': 'admin',
#                               'id': 'tinashemtapera@gmail.com'},
#                              {'access': 'admin', 'id': 'adebimpe@upenn.edu'},
#                              {'access': 'admin', 'id': 'mcieslak@upenn.edu'},
#                              {'access': 'admin', 'id': 'holder@upenn.edu'}],
#              'project': '5c1a61e69011bd0011368884',
#              'public': None,
#              'race': None,
#              'sex': None,
#              'species': None,
#              'strain': None,
#              'tags': None,
#              'type': None},
#  'tags': [],
#  'timestamp': datetime.datetime(2012, 8, 26, 18, 15, 59, tzinfo=tzutc()),
#  'timezone': 'America/New_York',
#  'uid': '12840113745101000100200041142438533706583',
#  'weight': None}

# %% [markdown]
# Notice that the use of `()` on a container returns an iteratable list, but without the function parentheses, the container is an in-built attribute that indexes the flywheel database:

# %%
type(project.subjects())
# Out:
# list

# %%
type(project.subjects)
# Out:
# flywheel.finder.Finder

# %% [markdown]
# The `get()` function can be used to go directly to a container:

# %%
subject = fw.get("5c1a82ca9011bd0015368ee6")

# %% [markdown]
# And while containers are not quite Russian nesting dolls, they can still be treated as such (project > subject > session > aqsuisition)

# %%
for ses in subject.sessions():
    print('%s: %s' % (ses.id, ses.label))
# Out:
# 5c1a82ca9011bd0015368ee7: neff2

# %%
ses1 = fw.get("5c1a82ca9011bd0015368ee7")

# %% [markdown]
# File are accessed via the `files` key, but it's easier to use `get()` on the BSON id.

# %%
f1 = fw.get("5c1a82ca9011bd0011368ed1")

# %%
f1.label
# Out:
# 'foo'

# %% [markdown]
# ## Viewing the data as Tabular
#
# Using `View()`, you can create a tabular index of the data you want to search through. From there, use `pandas` to present it as a dataframe:

# %%
import pandas as pd

view = fw.View(columns='subject')
df = fw.read_view_dataframe(view,project.id)
df.head()
# Out:
#                  project.id project.label  subject.cohort  subject.ethnicity  \
# 0  5c1a61e69011bd0011368884    Reward2018             NaN                NaN
# 1  5c1a61e69011bd0011368884    Reward2018             NaN                NaN
# 2  5c1a61e69011bd0011368884    Reward2018             NaN                NaN
# 3  5c1a61e69011bd0011368884    Reward2018             NaN                NaN
# 4  5c1a61e69011bd0011368884    Reward2018             NaN                NaN
#
#    subject.firstname                subject.id subject.label  \
# 0                NaN  5c1a70239011bd001436894c        100088
# 1                NaN  5c1a754e9011bd0014368976         90683
# 2                NaN  5c1a754e9011bd001436897a         91460
# 3                NaN  5c1a754e9011bd00153688a4         93204
# 4                NaN  5c1a754e9011bd00153688a6         93274
#
#    subject.lastname  subject.race subject.sex subject.species subject.strain  \
# 0               NaN           NaN        None            None           None
# 1               NaN           NaN      female            None           None
# 2               NaN           NaN        male            None           None
# 3               NaN           NaN      female            None           None
# 4               NaN           NaN      female            None           None
#
#   subject.type
# 0         None
# 1         None
# 2         None
# 3         None
# 4         None

# %% [markdown]
# In this implementation, there is a clear hierarchy to be followed. Basically, you specify the columns of the minor container you want to return, as members of some major container you have already assigned in the environment. So for example, if I wanted to see the name and size of all of the files of a session from a participant, I'd search the acquisition container, and execute it within the session container (`ses1` that was assigned earlier):

# %%
view = fw.View(columns=["file.size", "file.name"], container = "acquisition", filename = "*")
df = fw.read_view_dataframe(view, ses1.id)
df.head()
# Out:
#              acquisition.id    acquisition.label  \
# 0  5c1a82ca9011bd0013369086    ep2d_effort3_1416
# 1  5c1a82ca9011bd0011368ecf     ep2d_effort1_236
# 2  5c1a82ca9011bd0013369087  MPRAGE_TI1100_ipat2
# 3  5c1a82ca9011bd00143693a7              sag mpr
# 4  5c1a82ca9011bd0011368ed0     ep2d_effort2_236
#
#                        file.name  file.size                project.id  \
# 0    ep2d_effort3_1416.dicom.zip  420949340  5c1a61e69011bd0011368884
# 1     ep2d_effort1_236.dicom.zip   59804909  5c1a61e69011bd0011368884
# 2  MPRAGE_TI1100_ipat2.dicom.zip   11953289  5c1a61e69011bd0011368884
# 3              sag mpr.dicom.zip    6950815  5c1a61e69011bd0011368884
# 4     ep2d_effort2_236.dicom.zip   59917312  5c1a61e69011bd0011368884
#
#   project.label                session.id session.label  \
# 0    Reward2018  5c1a82ca9011bd0015368ee7         neff2
# 1    Reward2018  5c1a82ca9011bd0015368ee7         neff2
# 2    Reward2018  5c1a82ca9011bd0015368ee7         neff2
# 3    Reward2018  5c1a82ca9011bd0015368ee7         neff2
# 4    Reward2018  5c1a82ca9011bd0015368ee7         neff2
#
#                  subject.id  subject.label
# 0  5c1a82ca9011bd0015368ee6          19830
# 1  5c1a82ca9011bd0015368ee6          19830
# 2  5c1a82ca9011bd0015368ee6          19830
# 3  5c1a82ca9011bd0015368ee6          19830
# 4  5c1a82ca9011bd0015368ee6          19830

# %% [markdown]
# Note that to index and search through files, you must use the `container` and `filename` keywords in the View() function. The following function lists all of the available columns that can be used to tabularise flywheel containers:

# %%
fw.print_view_columns()
# Out:
# project (group): All column aliases belonging to project
# project.id (string): The project id
# project.label (string): The project label
# project.info (object): The freeform project metadata
# subject (group): All column aliases belonging to subject
# subject.id (string): The subject id
# subject.label (string): The subject label or code
# subject.firstname (string): The subject first name
# subject.lastname (string): The subject last name
# subject.sex (string): The subject sex (one of female|male|other|unknown)
# subject.race (string): The subject race (one of American Indian or Alaska Native|Asian|Native Hawaiian or Other Pacific Islander|Black or African American|White|More Than One Race|Unknown or Not Reported)
# subject.ethnicity (string): The subject ethnicity (one of Not Hispanic or Latino|Hispanic or Latino|Unknown or Not Reported)
# subject.cohort (string): The subject cohort (one of Control|Study|Training|Test|Validation)
# subject.type (string): The subject type (one of human|animal|phantom)
# subject.species (string): The subject species
# subject.strain (string): The subject strain
# subject.info (object): The freeform subject metadata
# session (group): All column aliases belonging to session
# session.id (string): The session id
# session.label (string): The session label
# session.operator (string): The session operator name
# session.timestamp (string): The session timestamp
# session.timezone (string): The session timezone
# session.info (object): The freeform session metadata
# session.age (int): The subject age at time of session, in seconds
# session.age_years (float): The subject age at time of session, in years
# session.age_months (float): The subject age at time of session, in months
# session.age_weeks (float): The subject age at time of session, in weeks
# session.age_days (float): The subject age at time of session, in days
# session.weight (float): The subject weight at time of session, in kg
# acquisition (group): All column aliases belonging to acquisition
# acquisition.id (string): The acquisition id
# acquisition.label (string): The acquisition label
# acquisition.timestamp (string): The acquisition timestamp
# acquisition.timezone (string): The acquisition timezone
# acquisition.info (object): The freeform acquisition metadata
# analysis (group): All column aliases belonging to analysis
# analysis.id (string): The analysis id
# analysis.label (string): The analysis label
# analysis.info (object): The freeform analysis metadata
# file (group): All column aliases belonging to file
# file.id (string): The file id
# file.name (string): The filename
# file.type (string): The type of file (e.g., dicom, image, document)
# file.mimetype (string): The file mime type (e.g. application/json, text/csv)
# file.modality (string): The file instrument type (e.g., MR, CT)
# file.classification (string): The file classification object
# file.size (int): The size of the file, in bytes
# file.row_number (int): The 0-indexed row number from file
# file.info (object): The freeform file metadata

# %% [markdown]
# ## Manipulating Data Values
#
# We can manipulate field values by passing a key-value pair to the `update()` function. Then, to update the object in the python environment, simply reassign it with `reload()`:

# %%
newname = {"label":"foo"}
f1.update(newname)
f1 = f1.reload()

# %%
f1.label
# Out:
# 'foo'

# %% [markdown]
# ## Checking for BIDS Validity
#
# Flywheel automatically tries to classify and organise your data into BIDS. The files of an acquisition have an `info` dict that can be used to check if the associated files were BIDS valid:

# %%
for acq in ses1.acquisitions():
    
    print "----------------"
    print "acquisition: " + acq.label
    print acq.info
    print
    for f in acq.files:
        print "file:"
        print f.name
        print f.classification
        print f.info
        print
# Out:
# ----------------
# acquisition: B0map_onesizefitsall_v4
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# B0map_onesizefitsall_v4.dicom.zip
# {}
# {u'BIDS': u'NA'}
#
# ----------------
# acquisition: MPRAGE_TI1100_ipat2
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# MPRAGE_TI1100_ipat2.dicom.zip
# {u'Intent': [u'Structural'], u'Measurement': [u'T1']}
# {u'BIDS': {u'error_message': u'', u'Filename': u'MPRAGE_TI1100_ipat2.dicom.zip', u'ignore': False, u'valid': True, u'template': u'dicom_file', u'Path': u'sourcedata/sub-19830/ses-neff2', u'Folder': u'sourcedata'}}
#
# file:
# MPRAGE_TI1100_ipat2_2.nii.gz
# {u'Intent': [u'Structural'], u'Measurement': [u'T1']}
# {u'BIDS': {u'Run': u'', u'error_message': u'', u'Ce': u'', u'Filename': u'sub-19830_ses-neff2_T1w.nii.gz', u'ignore': False, u'Acq': u'', u'valid': True, u'template': u'anat_file', u'Path': u'sub-19830/ses-neff2/anat', u'Rec': u'', u'Folder': u'anat', u'Modality': u'T1w', u'Mod': u''}}
#
# file:
# MPRAGE_TI1100_ipat2_2_mriqc.qa.html
# {u'Intent': [u'Structural'], u'Measurement': [u'T1']}
# {u'BIDS': u'NA'}
#
# ----------------
# acquisition: PhoenixZIPReport
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# PhoenixZIPReport.dicom.zip
# {u'Intent': [u'Non-Image']}
# {u'BIDS': u'NA'}
#
# ----------------
# acquisition: ep2d_effort1_236
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# ep2d_effort1_236.dicom.zip
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'error_message': u'', u'Filename': u'ep2d_effort1_236.dicom.zip', u'ignore': False, u'valid': True, u'template': u'dicom_file', u'Path': u'sourcedata/sub-19830/ses-neff2', u'Folder': u'sourcedata'}}
#
# file:
# ep2d_effort1_236_6.nii.gz
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'Task': u'', u'Run': u'', u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'", u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_sbref.nii.gz', u'ignore': False, u'Acq': u'', u'valid': False, u'template': u'func_file', u'Path': u'sub-19830/ses-neff2/func', u'Rec': u'', u'Folder': u'func', u'Echo': u'', u'Modality': u'sbref'}}
#
# file:
# ep2d_effort1_236_6_mriqc.qa.html
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': u'NA'}
#
# ----------------
# acquisition: ep2d_effort2_236
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# ep2d_effort2_236.dicom.zip
# {u'Intent': [u'Functional', u'Structural'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'error_message': u'', u'Filename': u'ep2d_effort2_236.dicom.zip', u'ignore': False, u'valid': True, u'template': u'dicom_file', u'Path': u'sourcedata/sub-19830/ses-neff2', u'Folder': u'sourcedata'}}
#
# file:
# ep2d_effort2_236_7.nii.gz
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'Task': u'', u'Run': u'', u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'", u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_sbref.nii.gz', u'ignore': False, u'Acq': u'', u'valid': False, u'template': u'func_file', u'Path': u'sub-19830/ses-neff2/func', u'Rec': u'', u'Folder': u'func', u'Echo': u'', u'Modality': u'sbref'}}
#
# file:
# ep2d_effort2_236_7_mriqc.qa.html
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': u'NA'}
#
# ----------------
# acquisition: ep2d_effort3_1416
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# ep2d_effort3_1416.dicom.zip
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'error_message': u'', u'Filename': u'ep2d_effort3_1416.dicom.zip', u'ignore': False, u'valid': True, u'template': u'dicom_file', u'Path': u'sourcedata/sub-19830/ses-neff2', u'Folder': u'sourcedata'}}
#
# file:
# ep2d_effort3_1416_8.nii.gz
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'Task': u'', u'Run': u'', u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'", u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_bold.nii.gz', u'ignore': False, u'Acq': u'', u'valid': False, u'template': u'func_file', u'Path': u'sub-19830/ses-neff2/func', u'Rec': u'', u'Folder': u'func', u'Echo': u'', u'Modality': u'bold'}}
#
# file:
# ep2d_effort3_1416_8_mriqc.qa.html
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': u'NA'}
#
# ----------------
# acquisition: ep2d_single
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# ep2d_single.dicom.zip
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'error_message': u'', u'Filename': u'ep2d_single.dicom.zip', u'ignore': False, u'valid': True, u'template': u'dicom_file', u'Path': u'sourcedata/sub-19830/ses-neff2', u'Folder': u'sourcedata'}}
#
# file:
# ep2d_single_3.nii.gz
# {u'Intent': [u'Functional'], u'Measurement': [u'T2*']}
# {u'BIDS': {u'Task': u'', u'Run': u'', u'error_message': u"Task u'' does not match '^[a-zA-Z0-9]+$'", u'Filename': u'sub-19830_ses-neff2_task-{file.info.BIDS.Task}_sbref.nii.gz', u'ignore': False, u'Acq': u'', u'valid': False, u'template': u'func_file', u'Path': u'sub-19830/ses-neff2/func', u'Rec': u'', u'Folder': u'func', u'Echo': u'', u'Modality': u'sbref'}}
#
# ----------------
# acquisition: foo
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# B0map_onesizefitsall_v4.dicom.zip
# {u'Custom': [], u'Intent': [u'Fieldmap'], u'Measurement': [u'B0']}
# {}
#
# file:
# B0map_onesizefitsall_v4_4_e2.nii.gz
# {u'Custom': [], u'Intent': [u'Fieldmap'], u'Measurement': [u'B0']}
# {}
#
# file:
# B0map_onesizefitsall_v4_4_e1.nii.gz
# {u'Custom': [], u'Intent': [u'Fieldmap'], u'Measurement': [u'B0']}
# {}
#
# ----------------
# acquisition: localizer
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# localizer.dicom.zip
# {u'Intent': [u'Localizer'], u'Measurement': [u'T2']}
# {u'BIDS': u'NA'}
#
# file:
# localizer_1_i00003.nii.gz
# {u'Intent': [u'Localizer'], u'Measurement': [u'T2']}
# {u'BIDS': u'NA'}
#
# file:
# localizer_1_i00002.nii.gz
# {u'Intent': [u'Localizer'], u'Measurement': [u'T2']}
# {u'BIDS': u'NA'}
#
# file:
# localizer_1_i00001.nii.gz
# {u'Intent': [u'Localizer'], u'Measurement': [u'T2']}
# {u'BIDS': u'NA'}
#
# ----------------
# acquisition: sag mpr
# {u'BIDS': {u'ignore': False, u'template': u'acquisition'}}
#
# file:
# sag mpr.dicom.zip
# {u'Intent': [u'Structural']}
# {u'BIDS': u'NA'}
#
# file:
# MPRAGE_TI1100_ipat2_100a.nii.gz
# {u'Intent': [u'Structural']}
# {}
#
# file:
# MPRAGE_TI1100_ipat2_100.nii.gz
# {u'Intent': [u'Structural']}
# {}

# %% [markdown]
# We can create a viewer of these files and use the file info object to assess whether or not the flywheel gear successfully classified the files in valid BIDS:

# %%
#build viewer
view = fw.View(columns=["file.info"], container = "acquisition", filename = "*")
df = fw.read_view_dataframe(view, ses1.id)
df
# Out:
#              acquisition.id        acquisition.label  \
# 0  5c1a82ca9011bd0013369086        ep2d_effort3_1416
# 1  5c1a82ca9011bd0011368ecf         ep2d_effort1_236
# 2  5c1a82ca9011bd0013369087      MPRAGE_TI1100_ipat2
# 3  5c1a82ca9011bd00143693a7                  sag mpr
# 4  5c1a82ca9011bd0011368ed0         ep2d_effort2_236
# 5  5c1a82ca9011bd0011368ed1                      foo
# 6  5c1a82ca9011bd00143693a8         PhoenixZIPReport
# 7  5c1a82ca9011bd0013369088  B0map_onesizefitsall_v4
# 8  5c1a82ca9011bd0013369089                localizer
# 9  5c1a82ca9011bd00143693a9              ep2d_single
#
#                                            file.info  \
# 0  {u'DeviceSerialNumber': u'167024', u'Photometr...
# 1  {u'DeviceSerialNumber': u'167024', u'Photometr...
# 2  {u'DeviceSerialNumber': u'167024', u'Photometr...
# 3  {u'DeviceSerialNumber': u'167024', u'Photometr...
# 4  {u'DeviceSerialNumber': u'167024', u'Photometr...
# 5                     {u'name': u'b0_map.dicom.zip'}
# 6  {u'AccessionNumber': u'29619771', u'ContentTim...
# 7  {u'RescaleSlope': 2, u'DeviceSerialNumber': u'...
# 8  {u'DeviceSerialNumber': u'167024', u'Photometr...
# 9  {u'DeviceSerialNumber': u'167024', u'Photometr...
#
#                  project.id project.label                session.id  \
# 0  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 1  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 2  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 3  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 4  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 5  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 6  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 7  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 8  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
# 9  5c1a61e69011bd0011368884    Reward2018  5c1a82ca9011bd0015368ee7
#
#   session.label                subject.id  subject.label
# 0         neff2  5c1a82ca9011bd0015368ee6          19830
# 1         neff2  5c1a82ca9011bd0015368ee6          19830
# 2         neff2  5c1a82ca9011bd0015368ee6          19830
# 3         neff2  5c1a82ca9011bd0015368ee6          19830
# 4         neff2  5c1a82ca9011bd0015368ee6          19830
# 5         neff2  5c1a82ca9011bd0015368ee6          19830
# 6         neff2  5c1a82ca9011bd0015368ee6          19830
# 7         neff2  5c1a82ca9011bd0015368ee6          19830
# 8         neff2  5c1a82ca9011bd0015368ee6          19830
# 9         neff2  5c1a82ca9011bd0015368ee6          19830

# %% [markdown]
# Using the acquisition ID, we can dig into the file information (which we looped over just above) and assess whether a nifti image was created, whether the BIDS key was created, and pull any info that was processed:

# %%
# eg get the ep2d from the above table
ep2d = fw.get("5c1a82ca9011bd0013369089")

# %%
# pull out only nifti files
niftis = [x for x in ep2d.files if x['type'] == 'nifti']

# %%
# check if the nifti file 'info' has bids
print([x['info'].keys() for x in niftis])
# Out:
# [[u'InPlanePhaseEncodingDirectionDICOM', u'ConsistencyInfo', u'ProcedureStepDescription', u'ReferringPhysicianName', u'AcquisitionMatrixPE', u'ImageOrientationPatientDICOM', u'PatientSex', u'ManufacturersModelName', u'ProtocolName', u'StudyID', u'ImageType', u'RepetitionTime', u'MagneticFieldStrength', u'PhaseEncodingSteps', u'MRAcquisitionType', u'SliceThickness', u'AcquisitionNumber', u'InstitutionName', u'DwellTime', u'TxRefAmp', u'BodyPartExamined', u'AcquisitionDateTime', u'SAR', u'PixelBandwidth', u'ScanningSequence', u'Manufacturer', u'ConversionSoftware', u'PercentPhaseFOV', u'DeviceSerialNumber', u'ReconMatrixPE', u'FlipAngle', u'InstitutionAddress', u'SeriesDescription', u'PartialFourier', u'ConversionSoftwareVersion', u'ShimSetting', u'PulseSequenceDetails', u'PatientPosition', u'SequenceName', u'StudyInstanceUID', u'SeriesNumber', u'SpacingBetweenSlices', u'ReceiveCoilActiveElements', u'ReceiveCoilName', u'EchoTime', u'SequenceVariant', u'PhaseResolution', u'BaseResolution', u'BIDS', u'PhaseEncodingDirection', u'PatientWeight', u'SoftwareVersions', u'StationName', u'SeriesInstanceUID', u'Modality', u'InstitutionalDepartmentName', u'AcquisitionTime'], [u'InPlanePhaseEncodingDirectionDICOM', u'ConsistencyInfo', u'ProcedureStepDescription', u'ReferringPhysicianName', u'AcquisitionMatrixPE', u'ImageOrientationPatientDICOM', u'PatientSex', u'ManufacturersModelName', u'ProtocolName', u'StudyID', u'ImageType', u'RepetitionTime', u'MagneticFieldStrength', u'PhaseEncodingSteps', u'MRAcquisitionType', u'SliceThickness', u'AcquisitionNumber', u'InstitutionName', u'DwellTime', u'TxRefAmp', u'BodyPartExamined', u'AcquisitionDateTime', u'SAR', u'PixelBandwidth', u'ScanningSequence', u'Manufacturer', u'ConversionSoftware', u'PercentPhaseFOV', u'DeviceSerialNumber', u'ReconMatrixPE', u'FlipAngle', u'InstitutionAddress', u'SeriesDescription', u'PartialFourier', u'ConversionSoftwareVersion', u'ShimSetting', u'PulseSequenceDetails', u'PatientPosition', u'SequenceName', u'StudyInstanceUID', u'SeriesNumber', u'SpacingBetweenSlices', u'ReceiveCoilActiveElements', u'ReceiveCoilName', u'EchoTime', u'SequenceVariant', u'PhaseResolution', u'BaseResolution', u'BIDS', u'PhaseEncodingDirection', u'PatientWeight', u'SoftwareVersions', u'StationName', u'SeriesInstanceUID', u'Modality', u'InstitutionalDepartmentName', u'AcquisitionTime'], [u'InPlanePhaseEncodingDirectionDICOM', u'ConsistencyInfo', u'ProcedureStepDescription', u'ReferringPhysicianName', u'AcquisitionMatrixPE', u'ImageOrientationPatientDICOM', u'PatientSex', u'ManufacturersModelName', u'ProtocolName', u'StudyID', u'ImageType', u'RepetitionTime', u'MagneticFieldStrength', u'PhaseEncodingSteps', u'MRAcquisitionType', u'SliceThickness', u'AcquisitionNumber', u'InstitutionName', u'DwellTime', u'TxRefAmp', u'BodyPartExamined', u'AcquisitionDateTime', u'SAR', u'PixelBandwidth', u'ScanningSequence', u'Manufacturer', u'ConversionSoftware', u'PercentPhaseFOV', u'DeviceSerialNumber', u'ReconMatrixPE', u'FlipAngle', u'InstitutionAddress', u'SeriesDescription', u'PartialFourier', u'ConversionSoftwareVersion', u'ShimSetting', u'PulseSequenceDetails', u'PatientPosition', u'SequenceName', u'StudyInstanceUID', u'SeriesNumber', u'SpacingBetweenSlices', u'ReceiveCoilActiveElements', u'ReceiveCoilName', u'EchoTime', u'SequenceVariant', u'PhaseResolution', u'BaseResolution', u'BIDS', u'PhaseEncodingDirection', u'PatientWeight', u'SoftwareVersions', u'StationName', u'SeriesInstanceUID', u'Modality', u'InstitutionalDepartmentName', u'AcquisitionTime']]

# %%
def ExtractBidsValidity(acquisitionID):
        
    '''
    A helper function to dig into the file.info object (a dictionary of dictionaries) and extract the BIDS validity value
    '''
    
    #create the acquisition object and pull the niftis
    acq = fw.get(acquisitionID)
    niftis = [x for x in acq.files if x['type'] == 'nifti']
    
    # if there are no niftis, return
    if (len(niftis) < 1):
        return None
    else:
        df = []
        
        #for each nifti, if the info has a BIDS dict:
        for nii in niftis:
            info = nii['info']
            if 'BIDS' in info.keys() and isinstance(info['BIDS'], dict):
                
                #also add the acquisition idto the dict for joining purposes
                nii['info']['BIDS']['acquisition.id'] = str(acquisitionID)
                
                #pull out the bids info
                df.append(nii['info']['BIDS'])
            else:
                return None

        return(df)

# %%
ExtractBidsValidity(df.loc[2,'acquisition.id'])
# Out:
# [{u'Acq': u'',
#   u'Ce': u'',
#   u'Filename': u'sub-19830_ses-neff2_T1w.nii.gz',
#   u'Folder': u'anat',
#   u'Mod': u'',
#   u'Modality': u'T1w',
#   u'Path': u'sub-19830/ses-neff2/anat',
#   u'Rec': u'',
#   u'Run': u'',
#   'acquisition.id': '5c1a82ca9011bd0013369087',
#   u'error_message': u'',
#   u'ignore': False,
#   u'template': u'anat_file',
#   u'valid': True}]

# %% [markdown]
# Here we loop over the rows to get all of the nifti bids info:

# %%
nifti_info = []

for ind, row in df.iterrows():
    temp_info = ExtractBidsValidity(row["acquisition.id"])
    if temp_info is not None:
        
        nifti_info.extend(temp_info)

# %% [markdown]
# And then we join merge the nifti info to the original query data frame:

# %%
niftis = pd.DataFrame(nifti_info)
df_with_niftis = pd.merge(df[['acquisition.id', 'acquisition.label', 'project.label', 'session.label', 'subject.label']], niftis, on="acquisition.id")

# %% [markdown]
# We can thus examine the exact nifti files that are not BIDS compliant:

# %%
df_with_niftis
# Out:
#              acquisition.id    acquisition.label project.label session.label  \
# 0  5c1a82ca9011bd0013369086    ep2d_effort3_1416    Reward2018         neff2
# 1  5c1a82ca9011bd0011368ecf     ep2d_effort1_236    Reward2018         neff2
# 2  5c1a82ca9011bd0013369087  MPRAGE_TI1100_ipat2    Reward2018         neff2
# 3  5c1a82ca9011bd0011368ed0     ep2d_effort2_236    Reward2018         neff2
# 4  5c1a82ca9011bd00143693a9          ep2d_single    Reward2018         neff2
#
#    subject.label Acq   Ce Echo  \
# 0          19830      NaN
# 1          19830      NaN
# 2          19830           NaN
# 3          19830      NaN
# 4          19830      NaN
#
#                                             Filename Folder  Mod Modality  \
# 0  sub-19830_ses-neff2_task-{file.info.BIDS.Task}...   func  NaN     bold
# 1  sub-19830_ses-neff2_task-{file.info.BIDS.Task}...   func  NaN    sbref
# 2                     sub-19830_ses-neff2_T1w.nii.gz   anat           T1w
# 3  sub-19830_ses-neff2_task-{file.info.BIDS.Task}...   func  NaN    sbref
# 4  sub-19830_ses-neff2_task-{file.info.BIDS.Task}...   func  NaN    sbref
#
#                        Path Rec Run Task  \
# 0  sub-19830/ses-neff2/func
# 1  sub-19830/ses-neff2/func
# 2  sub-19830/ses-neff2/anat          NaN
# 3  sub-19830/ses-neff2/func
# 4  sub-19830/ses-neff2/func
#
#                               error_message  ignore   template  valid
# 0  Task u'' does not match '^[a-zA-Z0-9]+$'   False  func_file  False
# 1  Task u'' does not match '^[a-zA-Z0-9]+$'   False  func_file  False
# 2                                             False  anat_file   True
# 3  Task u'' does not match '^[a-zA-Z0-9]+$'   False  func_file  False
# 4  Task u'' does not match '^[a-zA-Z0-9]+$'   False  func_file  False

# %% [markdown]
# We can wrap all of this work up in a script shown in the [next notebook](./Querying_BIDS_Validity.ipynb)
